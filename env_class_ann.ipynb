# %% [markdown]
# <a href="https://colab.research.google.com/github/Mumbawa/Computer_Science/blob/main/env_class_ann.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><h1><b>RED NEURONAL PARA LA CLASIFICACIÓN MORFOLÓGICA DE POZOS DE PETRÓLEO A PARTIR DE LA RESPUESTA DEL REGISTRO DE GAMMA RAY EMPLEANDO TÉCNICAS DE PROCESAMIENTO DE LENGUAJE NATURAL</b></h1></center>

# %% [markdown]
# # DEFINICIÓN DEL PROBLEMA

# %% [markdown]
# Un modelo geológico busca resolver tres preguntas ¿Qué rocas hay en el área?, ¿Cuál fue su ambiente de depósito?  Y ¿Qué geometría tienen las rocas en el área?, para responder a las dos primeras preguntas se podrían taladrar pozos extrayendo la roca intacta, pero al ser pozos de varios kilómetros de longitud esta solución es económicamente inviable.
#
# El método utilizado actualmente consiste en enviar una sonda con sensores de radiación gamma provenientes del Uranio, Torio y Potasio provenientes de las rocas. Esto permite clasificar las rocas en dos grupos: rocas arenosas (poco radioactivas) y rocas arcillosas (radioactivas).  A partir de los cambios en el tipo de roca a lo largo del pozo se identifican los diferentes **ambientes** de depósito.
#
# La interpretación del registro de rayos gamma esta sujeta del interprete en las definiciones de ¿Qué es una roca completamente arenosa?, ¿Qué es una roca completamente arcillosa?, ¿Cuáles son los limites de cada ambiente de depósito? Y ¿Cuál es la clasificación de cada ambiente?
#
# Este proyecto se enfoca en la ultima pregunta, busca reducir los tiempos de interpretacion asi como los posibles errores humanos en la clasificacion de los ambientes.
#
# La siguinete imagen ilustra la función  compĺe la red neuronal que se construyó; como se puede ver, la idea es que esta clasifique los diferentes ambientes (o secciones) que se presentan en un pozo de acuerdo a los tipo de ambientes teóricos que aparecen en la literatura.
#
# ![picture](https://drive.google.com/uc?export=view&id=1JZZENbe2-PY4AvjorbYsnLME3EGyR7jP)

# %% [markdown]
# # IMPORTACIÓN DE LIBRERIAS

# %%
import os
import sys
import math
import numpy             as np
import pandas            as pd
import random            as rd
import shutil            as sht
import tensorflow        as tf
import matplotlib.pyplot as plt
from   sklearn.decomposition       import PCA
from   sklearn.manifold            import TSNE
from   tensorflow.keras.optimizers import Adam
from   tensorflow.keras.models     import Model
from   tensorflow                  import keras
from   gensim.models               import word2vec
from   sklearn.decomposition       import KernelPCA
from   tensorflow.keras.utils      import plot_model
from   sklearn.model_selection     import train_test_split
from   tensorflow.keras.losses     import MeanSquaredError
from   tensorflow.keras.layers     import Input, Dense, Activation

# %% [markdown]
# # DEFINICIÓN DE FUNCIONES

# %%
#__________________________________________________________________________________________________

def Manejo_rutas (colab_o_local='local'):

    if colab_o_local == 'local':
        re = '../02_input'
        rs = '../03_output'
    elif colab_o_local == 'colab':

        from google.colab import drive
        drive.mount('/content/drive')

        re = '/content/drive/MyDrive/aux_diplomado/01_env_class_ann/02_input'
        rs = '/content/drive/MyDrive/aux_diplomado/01_env_class_ann/03_output'
    
    return re, rs
#__________________________________________________________________________________________________

def Borrar_result (rs):
        
    rutas =[rs + '/01_ambientes/todos_los_amb',
            rs + '/01_ambientes/amb_1',
            rs + '/01_ambientes/amb_2',
            rs + '/01_ambientes/amb_3',
            rs + '/01_ambientes/amb_4',
            rs + '/01_ambientes/amb_5',
            rs + '/01_ambientes/resumen_amb',
            rs + '/02_percentiles',
            rs + '/03_graficas/todos_los_amb',
            rs + '/03_graficas/amb_1',
            rs + '/03_graficas/amb_2',
            rs + '/03_graficas/amb_3',
            rs + '/03_graficas/amb_4',
            rs + '/03_graficas/amb_5']
    
    for i in rutas:
        aux = os.listdir(i)
        for j in aux:
            os.remove( i + '/' + j )
#__________________________________________________________________________________________________

def Df_amb (re, namb):
    with open (re + '/03_amb_pozos.txt', 'r') as fr:
        L_a_amb = [_.rstrip('\n').split(',') for _ in fr.readlines()]
        
    L_a_amb_dep = []
    for i in L_a_amb:
        if i != [''] and i[0][0] != '$':
            L_a_amb_dep.append( [ i[0], i[1].replace(' ',''), float(i[2]), float(i[3]) ])
            
    df_amb = pd.DataFrame(L_a_amb_dep, columns=['Pozo', 'Ambiente', 'Top', 'Bot'])

    if i == 1:
        return df_amb

    elif namb != 1:
        aux    = df_amb.groupby('Ambiente')
        df_amb = aux.sample(n=int (namb))
        return df_amb
#__________________________________________________________________________________________________

def GR_norm (GR, GR_inf, GR_sup):
    gr_nor = (GR-GR_inf) / (GR_sup-GR_inf)
    if gr_nor > 1.0:
        gr_nor = 1.0
    elif gr_nor < 0:
        gr_nor = 0.0
    return gr_nor
#__________________________________________________________________________________________________

def Zeros_fill (n_interv):
    
    if int (n_interv) <= 10:
        zeros_fill = int (1)
        return zeros_fill
    elif  10 < int (n_interv) <= 100:
        zeros_fill = int (2)
        return zeros_fill    
    elif  100 < int (n_interv) <= 1000:
        zeros_fill = int (3)
        return zeros_fill
    else:
        sys.exit('Error: El número de intervalos excede el valor permitido por la función'+
                  ' "Zeros_fill". Se debe modificar esta función para poder utilizar el número de'+
                  ' intervalos ingreasados.')
#__________________________________________________________________________________________________

def Codificacion (n_interv):

    lista_carct = []
    zeros_fill  = Zeros_fill(n_interv)
    
    for i in range (int(n_interv)):
        lista_carct.append('a' + str(i).zfill(zeros_fill))
    
    return lista_carct
#__________________________________________________________________________________________________

def Lista_interv (n_interv):
    
    len_interv  = 1 / n_interv
    list_interv = [] 
    codific     = Codificacion(n_interv)
    
    for i in range(int(n_interv)):
        if i == 0:
            interv = ( 0.0 , round(len_interv,8) , codific[i] )
            list_interv.append(interv)
            
        elif i < int(n_interv) - 1:
            interv=(round(list_interv[-1][1],8),round(list_interv[-1][1]+len_interv,8),\
                                                                            codific[i])
            list_interv.append(interv)
            
        elif i == int(n_interv) - 1:
            interv = ( round(list_interv[-1][1],8) , 1.0 , codific[i])
            list_interv.append(interv)
            
    return list_interv 
#__________________________________________________________________________________________________

def GRnorm_a_letra (GRnorm, list_interv):
    
    if np.isnan(GRnorm) == True:
        return np.nan                
    else:
        for i in range (len(list_interv)):
            if i <  len(list_interv) - 1:
                if GRnorm >= list_interv[i][0] and GRnorm < list_interv[i][1]:
                    return list_interv[i][2]                
            else:
                if GRnorm >= list_interv[i][0] and GRnorm <= list_interv[i][1]:
                    return list_interv[i][2]
#__________________________________________________________________________________________________

def Cent_no_cent (nom_pozo, conc,len_amb, Well_Df_Fil_Env):
    
    dept_i = Well_Df_Fil_Env['DEPT'].iloc[0]
    dept_j = Well_Df_Fil_Env['DEPT'].iloc[-1]
    
    ins_i = None
    ins_f = None
    
    if len(Well_Df_Fil_Env) >= len_amb:
        nramoi = True
    else:
        nramoi = False
        
    if conc == 1.0:
        
        if len(Well_Df_Fil_Env) > len_amb:
            aux1 = len(Well_Df_Fil_Env) - len_amb
            mod2 = round(aux1%2, 5)
            
            if mod2 == 0:
                aux2 = int(round(aux1/2,5))
                Well_Df_Fil_Env = Well_Df_Fil_Env.iloc[aux2:len(Well_Df_Fil_Env)-aux2].copy()
                ins_i = None
                ins_f = None
                
            if mod2!= 0:
                aux2 = round(aux1/2,5)
                aux3 = math.ceil(aux2)
                aux4 = aux3 - 1
                aux5 = [aux3,aux4]
                aux6 = rd.choice(aux5)
                aux5.remove(aux6)
                aux7 = aux5[0]
                Well_Df_Fil_Env = Well_Df_Fil_Env.iloc[aux6:len(Well_Df_Fil_Env)-aux7].copy()
                ins_i = None
                ins_f = None
                
        if len(Well_Df_Fil_Env) < len_amb:
            aux1 = abs(len(Well_Df_Fil_Env) - len_amb)
            mod2 = round(aux1%2, 5)
            
            if mod2 == 0:
                aux2 = int(round(aux1/2,5))
                aux3 = pd.Series(np.full(aux2, nom_pozo))
                aux4 = pd.Series(np.full(aux2, 0))
                aux5 = pd.concat([aux3,aux4,aux4,aux4,aux4], axis='columns')
                aux5.columns = ['WELLNAME','DEPT','GR','AMBIENTE','GR_NORM']
     
                Well_Df_Fil_Env = pd.concat([aux5,Well_Df_Fil_Env,aux5]).copy()
                
                ins_i = aux2
                ins_f = aux2
                
            if mod2!= 0:
                aux2  = round(aux1/2,5)
                aux3  = math.ceil(aux2)
                aux4  = aux3 - 1
                aux5  = [aux3,aux4]
                aux6  = rd.choice(aux5)
                aux5.remove(aux6)
                aux7  = aux5[0]
                
                aux8  = pd.Series(np.full(aux6, nom_pozo))
                aux9  = pd.Series(np.full(aux7, nom_pozo))
                
                aux10 = pd.Series(np.full(aux6, 0))
                aux11 = pd.Series(np.full(aux7, 0))
                
                aux12 = pd.concat([aux8,aux10,aux10,aux10,aux10], axis='columns')
                aux13 = pd.concat([aux9,aux11,aux11,aux11,aux11], axis='columns')
                
                aux12.columns = ['WELLNAME','DEPT','GR','AMBIENTE','GR_NORM']
                aux13.columns = ['WELLNAME','DEPT','GR','AMBIENTE','GR_NORM']
                
                Well_Df_Fil_Env = pd.concat([aux12,Well_Df_Fil_Env,aux13]).copy()
                
                ins_i = aux6
                ins_f = aux7
        
    return Well_Df_Fil_Env, nramoi, ins_i, ins_f, dept_i, dept_j
#__________________________________________________________________________________________________

def Graficar (nom_pozo, c_piso, dept_i, dept_j,ins_i,ins_f,nramoi,step, conc, len_env,
              env, l_cont, well_df_fil_amb, dmm,rs,g_graf):
    
    if g_graf == 1:
    
        nfgr=nom_pozo +'_niv_'+str(c_piso)+'_amb_'+env +'_'+str(l_cont[int(env)-1]).zfill(3)+'.png'
            
        if conc == 0.0:
            num_reg = len(well_df_fil_amb)
            plt.figure(figsize=(10./2.54,dmm/25.4 * num_reg), facecolor='whitesmoke')
            vec_prof    = well_df_fil_amb['DEPT']
            vec_GR_norm = well_df_fil_amb['GR_NORM']
            plt.ylim(well_df_fil_amb['DEPT'].iloc[0], well_df_fil_amb['DEPT'].iloc[-1])
            plt.fill_betweenx(vec_prof, vec_GR_norm, 0, zorder = 0, color ='silver')
            plt.fill_betweenx(vec_prof, vec_GR_norm, 1, zorder = 0, color = 'gold')
            
        elif conc == 1.0 and nramoi == True:
            plt.figure(figsize=(10./2.54,dmm/25.4 * len_env), facecolor='whitesmoke')
            vec_prof    = well_df_fil_amb['DEPT']
            vec_GR_norm = well_df_fil_amb['GR_NORM']
            plt.ylim(well_df_fil_amb['DEPT'].iloc[0], well_df_fil_amb['DEPT'].iloc[-1])
            plt.fill_betweenx(vec_prof, vec_GR_norm, 0, zorder = 0, color ='silver')
            plt.fill_betweenx(vec_prof, vec_GR_norm, 1, zorder = 0, color = 'gold')
            
        elif conc == 1.0 and nramoi == False:
            plt.figure(figsize=(10./2.54,dmm/25.4 * len_env), facecolor='whitesmoke')
            aux1  = step * ins_i
            aux2  = step * ins_f
            
            aux3 = dept_i - aux1
            aux4 = dept_j + aux2
            
            aux5 = [aux3  , dept_i] 
            aux6 = [dept_j, aux4]
            
            aux7 = [0,0]
            aux8 = [0,0]
            
            aux9 = well_df_fil_amb[(well_df_fil_amb['AMBIENTE']!=0) & (well_df_fil_amb['DEPT']!=0)]
            
            vec_prof    = aux5 + list(aux9['DEPT']) + aux6
            vec_GR_norm = aux7 + list(aux9['GR_NORM']) + aux8
            
            plt.ylim(aux3, aux4)
            plt.fill_betweenx(aux9['DEPT'], aux9['GR_NORM'], 0, zorder = 0, color ='silver')
            plt.fill_betweenx(aux9['DEPT'], aux9['GR_NORM'], 1, zorder = 0, color = 'gold')
            
        plt.plot(vec_GR_norm, vec_prof, linewidth=0.50, color='black')    
        plt.xlim(0,1)
        plt.gca().invert_yaxis()
        plt.grid()
        plt.title('PROF. VS G.R_norm\n(Pozo: {}, Nivel: {}, Amb.: {})'.format(nom_pozo,c_piso,env))
        plt.xlabel('GR_normalizado')
        plt.ylabel('Profundidad [ft]')
        plt.savefig(rs + '/03_graficas/todos_los_amb/'+nfgr, bbox_inches='tight',pad_inches=0.1)
        plt.close()
#__________________________________________________________________________________________________

def Gen_csv_amb (g_csv, well_df_fil_amb_cent_o_no,rs,nfile):
    if g_csv == 1:
        well_df_fil_amb_cent_o_no.to_csv(rs + '/01_ambientes/todos_los_amb/' + nfile, 
                                    index=False, columns=['DEPT','GR_NORM', 'CARACTER','AMBIENTE'])
#__________________________________________________________________________________________________

def Filt_top_bot (i,L_lin_ag_df, well_df, top, bot):
    
    if i < len(L_lin_ag_df) -1:
        filt = (well_df['DEPT'] >= top) & (well_df['DEPT'] < bot)
    else:
        filt = (well_df['DEPT'] >= top) & (well_df['DEPT'] <= bot)
        
    return filt
#__________________________________________________________________________________________________

def GR_qt_inf_sup (tg, well_df, nom_pozo):
    
    if tg == 0:
        GR_qt_inf = well_df['GR'].quantile(q_inf)
        GR_qt_sup = well_df['GR'].quantile(q_sup)
        return GR_qt_inf, GR_qt_sup
    
    if tg == 1:
        nom_pozo_aux = nom_pozo.split('_noi_')[0]
        GR_qt_inf    = df_tope.loc[nom_pozo_aux, 'Arena']
        GR_qt_sup    = df_tope.loc[nom_pozo_aux, 'Shale']
        return GR_qt_inf, GR_qt_sup
#__________________________________________________________________________________________________

def Guar_por_amb (rs,g_csv, g_graf):
    if g_csv == 1:
        ruta_csv = rs + '/01_ambientes/todos_los_amb'
        arch_csv = os.listdir(ruta_csv)
        for i in arch_csv:
            if 'amb_1' in i:
                sht.copyfile(ruta_csv + '/' +i, ruta_csv[:-13] + 'amb_1'+'/'+i)
            elif 'amb_2' in i:
                sht.copyfile(ruta_csv + '/' +i, ruta_csv[:-13] + 'amb_2'+'/'+i)
            elif 'amb_3' in i:
                sht.copyfile(ruta_csv + '/' +i, ruta_csv[:-13] + 'amb_3'+'/'+i)
            elif 'amb_4' in i:
                sht.copyfile(ruta_csv + '/' +i, ruta_csv[:-13] + 'amb_4'+'/'+i)
            elif 'amb_5' in i:
                sht.copyfile(ruta_csv + '/' +i, ruta_csv[:-13] + 'amb_5'+'/'+i)
    
    if g_graf == 1:
        ruta_grf = rs + '/03_graficas/todos_los_amb'
        arch_grf = os.listdir(ruta_grf)
        for i in arch_grf:
            if 'amb_1' in i:
                sht.copyfile(ruta_grf + '/' +i, ruta_grf[:-13] + 'amb_1'+'/'+i)
            elif 'amb_2' in i:
                sht.copyfile(ruta_grf + '/' +i, ruta_grf[:-13] + 'amb_2'+'/'+i)
            elif 'amb_3' in i:
                sht.copyfile(ruta_grf + '/' +i, ruta_grf[:-13] + 'amb_3'+'/'+i)
            elif 'amb_4' in i:
                sht.copyfile(ruta_grf + '/' +i, ruta_grf[:-13] + 'amb_4'+'/'+i)
            elif 'amb_5' in i:
                sht.copyfile(ruta_grf + '/' +i, ruta_grf[:-13] + 'amb_5'+'/'+i)
#__________________________________________________________________________________________________

def Read_ent_gen (re):
    ent_gen = list(np.loadtxt(re + '/01_dat_gen.txt', skiprows=2,usecols=0))
    ent_gen[0] = int(ent_gen[0])
    return ent_gen
#__________________________________________________________________________________________________

# %% [markdown]
# # PREPROCESAMIENTO DE DATOS

# %% [markdown]
# ## IMPLEMENTACIÓN DEL RUIDO GAUSSIANO

# %% [markdown]
# Ya que el proceso de obtención de mediciones de Gamma Ray (GR) en pozos de petróleos es bastante costoso para las empresas, no fue factible para el proceso de entrenamiento de la red tener una gran cantidad de muestras de forma gratuita.  Para solucionar esto se optó por generar gráficas de GR para el entrenamiento de manera artificial usuando ruidos gausianos a una magnitud que no modifique la clasificación asignada inicialmente al ambiente.
#
# La siguiente imagen ilustra la idea anterior:
#
# ![picture](https://drive.google.com/uc?export=view&id=1o2HG36rgjIFLdZ2ZzKgm9yNg5_94xrnb)
#
# En la anterior imagen, la gráfica izquierda corresponde al registro original, mientras que la derecha tiene aplicado el ruido gaussiano.
#
# Para el proceso de entrenamiento se generaron $25$ registros con ruido gaussiano por cada registro original.

# %%
#__________________________________________________________________________________________________

re, rs = Manejo_rutas (colab_o_local='colab')

Borrar_result(rs)

n,factor, quant,namb, conc,g_csv,g_graf,len_env,tg,q_inf,q_sup,step,n_interv,dmm=Read_ent_gen (re)

df_amb       = Df_amb(re,namb)
L_nom_pozos  = list (df_amb['Pozo'].unique())

df  = pd.read_csv(re + '/02_data_set_well_logs.csv', usecols=[5,17,20])[['WELLNAME','DEPT','GR']]
df.set_index('WELLNAME',inplace=True)
df           = df.loc[L_nom_pozos].reset_index()
well_grp_df_rg  = df.groupby('WELLNAME', sort=False)
#__________________________________________________________________________________________________

for nom_pozo in L_nom_pozos:
    
    well_df = well_grp_df_rg.get_group(nom_pozo).copy().reset_index(drop=True)
    GR_quant = well_df['GR'].quantile(quant)
    
    for i in range(n):
        
        well_df_noise = well_df.copy()
        well_df_noise['GR'] = well_df_noise['GR'].apply\
            (lambda x: x + np.random.normal()*factor*GR_quant)
            
        well_df_noise['WELLNAME'] = nom_pozo + '_noi_' + str(i+1)
        
        df = df.append(well_df_noise,ignore_index=True)
#__________________________________________________________________________________________________
        
well_grp_df_amb  = df_amb.groupby('Pozo', sort=False)
for i in well_grp_df_amb:
    for j in range(n):
        df_noi_ij = i[1].copy()
        df_noi_ij['Pozo'] = i[0] + '_noi_' + str (j+1)
        df_amb = df_amb.append(df_noi_ij,ignore_index=True)
#__________________________________________________________________________________________________
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## OBTENCIÓN DEL CORPUS

# %% [markdown]
# Uno de los principales problemas de este estudio proviene del hecho de que cada medición de Gamma Ray (GR) para un pozo tiene una cantidad de registros altamente variable y por lo tanto los ambientes serán considerablemente variables en longitud. Para trabajar con estos conjuntos de longitudes desiguales se decidió abordar el problema como un problema de ***procesamiento del lenguaje natural***.
#
# Ya que el rango de los datos permanece entre $[0,1]$ se dividió el intervalo en 100 subintervalos de $0.01$ y se le asignó a cada uno de los intervalos las palabras desde $a00$ hasta $a99$ siendo así cada ambiente un documento de texto.
#
# Para el presente estudio se tokenizó cada documento por palabras, de forma que el corpus del análisis se constituye por el conjunto de palabras $\{a00,...,a99\}$.
#
# El siguente esquema ilustra lo anterior:
#
# ![picture](https://drive.google.com/uc?export=view&id=1CsaculFAU3FpdOifSu6wOqP6BnbhL4xt)

# %%
#__________________________________________________________________________________________________

list_interv = Lista_interv(n_interv)

df['DEPT']  = (df['DEPT']/0.3048).round(8)    
well_grp_df = df.groupby('WELLNAME')

well_grp_df_amb  = df_amb.groupby('Pozo', sort=False)

df_tope =  pd.read_csv(re + '/04_bases_arena_shale.csv',
                        dtype={'Arena':float, 'Shale':float}).set_index('Pozo')
#__________________________________________________________________________________________________

l_perc     = []
l_cont     = [0,0,0,0,0]
l_resm_env = []
corpus     = []
label_amb  = []

for amb_pozo in well_grp_df_amb:

    nom_pozo    = amb_pozo[0]
    L_lin_ag_df = amb_pozo[1].drop('Pozo', axis='columns')
    L_lin_ag_df['Ambiente'] = L_lin_ag_df['Ambiente'].astype(str)

    #______________________________________________________________________________________________
    
    well_df   = well_grp_df.get_group(nom_pozo).copy().reset_index(drop=True)
    
    GR_min    = well_df['GR'].min()
    GR_max    = well_df['GR'].max()
    GR_qt_inf, GR_qt_sup = GR_qt_inf_sup (tg, well_df, nom_pozo)
    #______________________________________________________________________________________________
    
    c_piso = 0
    for i in range(len(L_lin_ag_df)):
        
        c_piso += 1
        
        env  = L_lin_ag_df.iloc[i,0]
        top  = L_lin_ag_df.iloc[i,1]
        bot  = L_lin_ag_df.iloc[i,2]
        
        filt = Filt_top_bot (i,L_lin_ag_df, well_df, top, bot)
            
        well_df_fil_amb = well_df[filt].copy()
        
        well_df_fil_amb['AMBIENTE'] = env
        well_df_fil_amb['GR_NORM']  = well_df_fil_amb['GR'].apply(GR_norm, 
                                                            args=(GR_qt_inf,GR_qt_sup))
        
        well_df_fil_amb_cent_o_no,nramoi,ins_i,ins_f,dept_i, dept_j =Cent_no_cent(nom_pozo,conc,
                                                                        len_env,well_df_fil_amb)
                                                  
        well_df_fil_amb_cent_o_no['CARACTER'] = well_df_fil_amb_cent_o_no['GR_NORM'].apply\
                                                              (GRnorm_a_letra, args=(list_interv,))
        
        corpus.append(list (well_df_fil_amb_cent_o_no['CARACTER']))
        label_amb.append(env)        
        
        l_cont[int(env)-1] = l_cont[int(env)-1] + 1                                          
        
        Graficar(nom_pozo, c_piso,dept_i, dept_j,ins_i,ins_f,nramoi, step, conc, len_env, env,
                                                    l_cont,well_df_fil_amb_cent_o_no,dmm,rs,g_graf)     
                    
        nfile=nom_pozo+'_niv_'+str(c_piso)+'_amb_'+env +'_'+str(l_cont[int(env)-1]).zfill(3)+'.csv'
        
        Gen_csv_amb (g_csv, well_df_fil_amb_cent_o_no,rs,nfile)
        
        l_resm_env.append([nfile[:-4],int(env),nom_pozo,c_piso,top,bot])
#__________________________________________________________________________________________________

resm_df = pd.DataFrame(l_resm_env,columns=['Nombre_amb','Ambiente','Pozo','Nivel', 'Top','Bot']) 
if g_csv == 1:                                                            
    resm_df.to_csv(rs + '/01_ambientes/resumen_amb/Resumen_ambientes.csv',index=False)

perc_df = pd.DataFrame(l_perc,columns=['POZO','GR_MIN','GR_MAX','GR_PER_5','GR_PER_95'])  
if g_csv == 1:                                                            
    perc_df.to_csv(rs + '/02_percentiles/GR_perc_pozos.csv',index=False)

Guar_por_amb(rs,g_csv, g_graf)
#__________________________________________________________________________________________________

# %% [markdown]
# ## DEPURACIÓN DEL CORPUS - ELIMINACIÓN DE VALORES nan

# %% [markdown]
# Dado que la sonda que se envía para tomar los registros de Gamma Ray puede dejar de tomar registros en ciertos puntos por diversos problemas que se puedan presentar (por ejemplo: se derrumba las paredes de la performación lo cual afecta el equipo), en algunos pozos con los que trabajó no se tiene registro de Gamma Ray en cierto rango de profundidades. Para solucionar este incoveniente de valores faltantes, se optó por suprimir estos registros. El siguiente esquema ilustra lo anterior:
#
# ![picture](https://drive.google.com/uc?export=view&id=1bD2st1u1XXtoJdzBBaaagS8Pvh7SqqYI)

# %%
corpus_s_nan = []
for i in corpus:
    corpus_s_nan.append(list (pd.Series(i).dropna()))

# %% [markdown]
# ## DEFINICIÓN DEL CONJUNTO DE DATOS DE ENTRENAMIENTO Y PRUEBA

# %%
random_state = 60
x_train, x_test, y_train, y_test = train_test_split(corpus_s_nan, label_amb, test_size=0.20,
                                                                  random_state=random_state)

# %% [markdown]
# ## TRANSFORMACIÓN DE LOS ELEMENTOS DEL CORPUS (TEXTO A VECTORES) EMPLEANDO Word2Vec

# %% [markdown]
# Como función de embedding se utilizó *word2vec* con el fin de transformar cada palabra en un vector de $10$ entradas y posteriormente obtener un vector representativo (también de $10$ entradas) de cada documento por medio de promediar cada conjunto de vectores que lo conforman.
#
# Una ventaja importante del método recien descrito, es que al final todos los registros (que inicialmente tenían longitudes variables) van a tener la misma longitud ($10$), lo cual facilita la construcción de la red neuronal, pues la capa de entrada será siempre de $10$ neuronas (como se verá más adelnate).
#
# La siquiente gráfica ilustra lo anterior:
#
# ![picture](https://drive.google.com/uc?export=view&id=10flF5HKgNdjXEIOWHqalIDA_p-H7FEt3)
#
# Se decidió utilizar una ventana de contexto de 100 palabras con el fin de recoger en longitud física un total de 30 metros, que según nuestro experto es en promedio las distancias en las que se presentan cambios importantes en los pozos.

# %%
feature_size   = 10
window_context = 100                        
min_word_count = 1
sample         = 1e-3

w2v_model = word2vec.Word2Vec(x_train, window=window_context, 
                              min_count=min_word_count, sample=sample, size=feature_size)
                          
wvs = w2v_model.wv[Codificacion (n_interv)]

dict_pal_vec = dict (zip(Codificacion (n_interv) ,  wvs))

corp_transf_train  = []

for i in x_train:
    aux  = [] 
    for j in i:
        aux.append(dict_pal_vec[j])
    prom = np.mean(np.array(aux),axis=0)
    corp_transf_train.append(list (prom))

corp_transf_train_np = np.array(corp_transf_train)

# %% [markdown]
# # RED NEURONAL

# %% [markdown]
# ## DEFINICIÓN DE LA ARQUITECTURA DE LA RED NEURONAL

# %% [markdown]
# El problema en sí es un problema básico de clasificación, una vez obtenidos los tensores representativos de cada documento de tamaño estándar se procede a alimentar una red con una capa de entrada de 10 neuronas y dos capaz densas de 20 y 10 neuronas con activación relu y una capa de salida softmax con 5 neuronas las cuales representan las 5 clases de ambientes.

# %%
# Construcción del modelo

model = keras.models.Sequential([
 keras.layers.Input(shape=[10,]),
 keras.layers.Dense(20, activation="relu"),
 keras.layers.Dense(10, activation="relu"),
 keras.layers.Dense(5 , activation="softmax")
])

# Parámetros del modelo

model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer = 'adam',
              metrics = 'accuracy')

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 20)                220
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 55
# =================================================================
# Total params: 485
# Trainable params: 485
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## ENTRENAMIENTO DE LA RED NEURONAL

# %%
history = model.fit(corp_transf_train_np, np.array(y_train,dtype=int) - 1, epochs = 3000, 
                                                                   validation_split=0.1)

# En esta parte se guarda el modelo
aux = os.listdir(rs + '/04_ann_model')
aux1 = str (len(aux)+1).zfill(2)
model.save(rs + '/04_ann_model/' +'execution_'+aux1+'_ann_results' + '/ann_model.h5')
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 501/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0337 - accuracy: 0.9938 - val_loss: 0.0428 - val_accuracy: 0.9876
# Epoch 502/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 0.9927 - val_loss: 0.0455 - val_accuracy: 0.9860
# Epoch 503/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0385 - accuracy: 0.9898 - val_loss: 0.0449 - val_accuracy: 0.9860
# Epoch 504/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9918 - val_loss: 0.0715 - val_accuracy: 0.9783
# Epoch 505/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0473 - accuracy: 0.9851 - val_loss: 0.0526 - val_accuracy: 0.9829
# Epoch 506/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0371 - accuracy: 0.9898 - val_loss: 0.0530 - val_accuracy: 0.9860
# Epoch 507/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9913 - val_loss: 0.0429 - val_accuracy: 0.9891
# Epoch 508/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9908 - val_loss: 0.0433 - val_accuracy: 0.9860
# Epoch 509/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 0.9920 - val_loss: 0.0367 - val_accuracy: 0.9891
# Epoch 510/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0381 - accuracy: 0.9904 - val_loss: 0.0488 - val_accuracy: 0.9845
# Epoch 511/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 0.9914 - val_loss: 0.0399 - val_accuracy: 0.9891
# Epoch 512/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 0.9934 - val_loss: 0.0413 - val_accuracy: 0.9876
# Epoch 513/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 0.9906 - val_loss: 0.0410 - val_accuracy: 0.9860
# Epoch 514/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0320 - accuracy: 0.9918 - val_loss: 0.0434 - val_accuracy: 0.9891
# Epoch 515/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9903 - val_loss: 0.0496 - val_accuracy: 0.9860
# Epoch 516/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9905 - val_loss: 0.0430 - val_accuracy: 0.9891
# Epoch 517/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0479 - accuracy: 0.9863 - val_loss: 0.0892 - val_accuracy: 0.9736
# Epoch 518/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0385 - accuracy: 0.9898 - val_loss: 0.0473 - val_accuracy: 0.9860
# Epoch 519/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 0.9915 - val_loss: 0.0370 - val_accuracy: 0.9938
# Epoch 520/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 0.9914 - val_loss: 0.2757 - val_accuracy: 0.9411
# Epoch 521/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0488 - accuracy: 0.9890 - val_loss: 0.0442 - val_accuracy: 0.9922
# Epoch 522/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 0.9929 - val_loss: 0.0641 - val_accuracy: 0.9783
# Epoch 523/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0347 - accuracy: 0.9907 - val_loss: 0.0725 - val_accuracy: 0.9798
# Epoch 524/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 0.9889 - val_loss: 0.0483 - val_accuracy: 0.9845
# Epoch 525/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 0.9888 - val_loss: 0.0451 - val_accuracy: 0.9891
# Epoch 526/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0290 - accuracy: 0.9945 - val_loss: 0.0470 - val_accuracy: 0.9860
# Epoch 527/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 0.9929 - val_loss: 0.0376 - val_accuracy: 0.9907
# Epoch 528/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 0.9921 - val_loss: 0.0390 - val_accuracy: 0.9891
# Epoch 529/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 0.9926 - val_loss: 0.0381 - val_accuracy: 0.9922
# Epoch 530/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 0.9904 - val_loss: 0.0368 - val_accuracy: 0.9907
# Epoch 531/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 0.9957 - val_loss: 0.0615 - val_accuracy: 0.9829
# Epoch 532/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9892 - val_loss: 0.0426 - val_accuracy: 0.9891
# Epoch 533/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9953 - val_loss: 0.0366 - val_accuracy: 0.9891
# Epoch 534/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9941 - val_loss: 0.0416 - val_accuracy: 0.9876
# Epoch 535/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 0.9939 - val_loss: 0.0492 - val_accuracy: 0.9860
# Epoch 536/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0373 - accuracy: 0.9903 - val_loss: 0.0405 - val_accuracy: 0.9891
# Epoch 537/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0336 - accuracy: 0.9915 - val_loss: 0.0365 - val_accuracy: 0.9938
# Epoch 538/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9947 - val_loss: 0.0500 - val_accuracy: 0.9845
# Epoch 539/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9920 - val_loss: 0.0517 - val_accuracy: 0.9876
# Epoch 540/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0365 - accuracy: 0.9919 - val_loss: 0.0553 - val_accuracy: 0.9845
# Epoch 541/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0374 - accuracy: 0.9924 - val_loss: 0.0416 - val_accuracy: 0.9876
# Epoch 542/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9918 - val_loss: 0.0408 - val_accuracy: 0.9876
# Epoch 543/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 0.9938 - val_loss: 0.0388 - val_accuracy: 0.9891
# Epoch 544/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0333 - accuracy: 0.9927 - val_loss: 0.0320 - val_accuracy: 0.9938
# Epoch 545/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0363 - accuracy: 0.9912 - val_loss: 0.0832 - val_accuracy: 0.9798
# Epoch 546/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0521 - accuracy: 0.9839 - val_loss: 0.0454 - val_accuracy: 0.9845
# Epoch 547/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 0.9932 - val_loss: 0.0463 - val_accuracy: 0.9845
# Epoch 548/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 0.9917 - val_loss: 0.0399 - val_accuracy: 0.9907
# Epoch 549/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0311 - accuracy: 0.9937 - val_loss: 0.0472 - val_accuracy: 0.9876
# Epoch 550/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9948 - val_loss: 0.0368 - val_accuracy: 0.9891
# Epoch 551/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9898 - val_loss: 0.0432 - val_accuracy: 0.9860
# Epoch 552/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 0.9938 - val_loss: 0.0402 - val_accuracy: 0.9907
# Epoch 553/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0273 - accuracy: 0.9942 - val_loss: 0.0405 - val_accuracy: 0.9876
# Epoch 554/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9941 - val_loss: 0.0490 - val_accuracy: 0.9845
# Epoch 555/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9934 - val_loss: 0.0411 - val_accuracy: 0.9876
# Epoch 556/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 0.9907 - val_loss: 0.0338 - val_accuracy: 0.9938
# Epoch 557/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9931 - val_loss: 0.0406 - val_accuracy: 0.9907
# Epoch 558/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9913 - val_loss: 0.0362 - val_accuracy: 0.9922
# Epoch 559/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 0.9925 - val_loss: 0.0827 - val_accuracy: 0.9674
# Epoch 560/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.9845 - val_loss: 0.0431 - val_accuracy: 0.9860
# Epoch 561/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 0.9929 - val_loss: 0.0365 - val_accuracy: 0.9907
# Epoch 562/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 0.9952 - val_loss: 0.0342 - val_accuracy: 0.9891
# Epoch 563/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0290 - accuracy: 0.9943 - val_loss: 0.0355 - val_accuracy: 0.9907
# Epoch 564/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 0.9941 - val_loss: 0.0426 - val_accuracy: 0.9860
# Epoch 565/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0290 - accuracy: 0.9937 - val_loss: 0.0396 - val_accuracy: 0.9860
# Epoch 566/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 0.9941 - val_loss: 0.0402 - val_accuracy: 0.9891
# Epoch 567/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9936 - val_loss: 0.0559 - val_accuracy: 0.9845
# Epoch 568/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 0.9952 - val_loss: 0.0344 - val_accuracy: 0.9953
# Epoch 569/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9924 - val_loss: 0.0433 - val_accuracy: 0.9907
# Epoch 570/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0327 - accuracy: 0.9920 - val_loss: 0.0344 - val_accuracy: 0.9938
# Epoch 571/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 0.9938 - val_loss: 0.0375 - val_accuracy: 0.9891
# Epoch 572/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9961 - val_loss: 0.0474 - val_accuracy: 0.9814
# Epoch 573/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0295 - accuracy: 0.9927 - val_loss: 0.0408 - val_accuracy: 0.9922
# Epoch 574/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 0.9937 - val_loss: 0.0342 - val_accuracy: 0.9907
# Epoch 575/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9937 - val_loss: 0.0434 - val_accuracy: 0.9891
# Epoch 576/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9957 - val_loss: 0.0397 - val_accuracy: 0.9922
# Epoch 577/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0602 - accuracy: 0.9828 - val_loss: 0.0408 - val_accuracy: 0.9891
# Epoch 578/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9938 - val_loss: 0.0455 - val_accuracy: 0.9891
# Epoch 579/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 0.9926 - val_loss: 0.0343 - val_accuracy: 0.9953
# Epoch 580/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9962 - val_loss: 0.0487 - val_accuracy: 0.9845
# Epoch 581/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9918 - val_loss: 0.0367 - val_accuracy: 0.9891
# Epoch 582/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 0.9925 - val_loss: 0.0374 - val_accuracy: 0.9907
# Epoch 583/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0360 - accuracy: 0.9918 - val_loss: 0.0463 - val_accuracy: 0.9845
# Epoch 584/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0354 - accuracy: 0.9893 - val_loss: 0.0508 - val_accuracy: 0.9829
# Epoch 585/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 0.9945 - val_loss: 0.0386 - val_accuracy: 0.9876
# Epoch 586/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9966 - val_loss: 0.0310 - val_accuracy: 0.9922
# Epoch 587/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 0.9958 - val_loss: 0.0414 - val_accuracy: 0.9876
# Epoch 588/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 0.9950 - val_loss: 0.0324 - val_accuracy: 0.9907
# Epoch 589/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9931 - val_loss: 0.0387 - val_accuracy: 0.9860
# Epoch 590/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0297 - accuracy: 0.9937 - val_loss: 0.0451 - val_accuracy: 0.9907
# Epoch 591/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0327 - accuracy: 0.9914 - val_loss: 0.0305 - val_accuracy: 0.9953
# Epoch 592/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9917 - val_loss: 0.0340 - val_accuracy: 0.9891
# Epoch 593/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 0.9922 - val_loss: 0.0448 - val_accuracy: 0.9876
# Epoch 594/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0391 - accuracy: 0.9913 - val_loss: 0.0380 - val_accuracy: 0.9907
# Epoch 595/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9950 - val_loss: 0.0341 - val_accuracy: 0.9938
# Epoch 596/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9954 - val_loss: 0.0373 - val_accuracy: 0.9922
# Epoch 597/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9932 - val_loss: 0.0379 - val_accuracy: 0.9891
# Epoch 598/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0327 - accuracy: 0.9911 - val_loss: 0.0366 - val_accuracy: 0.9876
# Epoch 599/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9977 - val_loss: 0.0400 - val_accuracy: 0.9876
# Epoch 600/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9916 - val_loss: 0.0350 - val_accuracy: 0.9907
# Epoch 601/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9940 - val_loss: 0.0453 - val_accuracy: 0.9860
# Epoch 602/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9956 - val_loss: 0.0366 - val_accuracy: 0.9907
# Epoch 603/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9899 - val_loss: 0.0322 - val_accuracy: 0.9922
# Epoch 604/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9954 - val_loss: 0.0293 - val_accuracy: 0.9953
# Epoch 605/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9939 - val_loss: 0.0305 - val_accuracy: 0.9876
# Epoch 606/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 0.9933 - val_loss: 0.0285 - val_accuracy: 0.9938
# Epoch 607/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9939 - val_loss: 0.0325 - val_accuracy: 0.9891
# Epoch 608/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.9978 - val_loss: 0.0575 - val_accuracy: 0.9783
# Epoch 609/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 0.9904 - val_loss: 0.0549 - val_accuracy: 0.9829
# Epoch 610/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9949 - val_loss: 0.0321 - val_accuracy: 0.9891
# Epoch 611/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0244 - accuracy: 0.9951 - val_loss: 0.0352 - val_accuracy: 0.9907
# Epoch 612/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 0.9946 - val_loss: 0.0362 - val_accuracy: 0.9907
# Epoch 613/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9953 - val_loss: 0.0322 - val_accuracy: 0.9938
# Epoch 614/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 0.9943 - val_loss: 0.0355 - val_accuracy: 0.9922
# Epoch 615/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 0.9974 - val_loss: 0.0420 - val_accuracy: 0.9876
# Epoch 616/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9944 - val_loss: 0.0400 - val_accuracy: 0.9876
# Epoch 617/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 0.9906 - val_loss: 0.0732 - val_accuracy: 0.9845
# Epoch 618/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 0.9965 - val_loss: 0.0305 - val_accuracy: 0.9922
# Epoch 619/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 0.9966 - val_loss: 0.0408 - val_accuracy: 0.9891
# Epoch 620/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9970 - val_loss: 0.0310 - val_accuracy: 0.9922
# Epoch 621/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9959 - val_loss: 0.0304 - val_accuracy: 0.9907
# Epoch 622/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 0.9965 - val_loss: 0.0374 - val_accuracy: 0.9860
# Epoch 623/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9940 - val_loss: 0.0326 - val_accuracy: 0.9922
# Epoch 624/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9938 - val_loss: 0.0326 - val_accuracy: 0.9907
# Epoch 625/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9979 - val_loss: 0.0396 - val_accuracy: 0.9891
# Epoch 626/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9965 - val_loss: 0.0455 - val_accuracy: 0.9876
# Epoch 627/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0412 - accuracy: 0.9912 - val_loss: 0.0308 - val_accuracy: 0.9922
# Epoch 628/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9951 - val_loss: 0.0356 - val_accuracy: 0.9876
# Epoch 629/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0602 - accuracy: 0.9883 - val_loss: 0.0429 - val_accuracy: 0.9922
# Epoch 630/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9966 - val_loss: 0.0274 - val_accuracy: 0.9922
# Epoch 631/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 0.9957 - val_loss: 0.0305 - val_accuracy: 0.9953
# Epoch 632/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9979 - val_loss: 0.0301 - val_accuracy: 0.9922
# Epoch 633/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0445 - accuracy: 0.9878 - val_loss: 0.0425 - val_accuracy: 0.9876
# Epoch 634/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 0.9914 - val_loss: 0.0413 - val_accuracy: 0.9876
# Epoch 635/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9966 - val_loss: 0.0272 - val_accuracy: 0.9938
# Epoch 636/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 0.9958 - val_loss: 0.0281 - val_accuracy: 0.9907
# Epoch 637/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9976 - val_loss: 0.0387 - val_accuracy: 0.9922
# Epoch 638/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 0.9961 - val_loss: 0.0392 - val_accuracy: 0.9860
# Epoch 639/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0588 - accuracy: 0.9891 - val_loss: 0.0369 - val_accuracy: 0.9907
# Epoch 640/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9969 - val_loss: 0.0299 - val_accuracy: 0.9922
# Epoch 641/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9981 - val_loss: 0.0422 - val_accuracy: 0.9876
# Epoch 642/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9952 - val_loss: 0.0365 - val_accuracy: 0.9876
# Epoch 643/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 0.9952 - val_loss: 0.0355 - val_accuracy: 0.9907
# Epoch 644/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.9975 - val_loss: 0.0316 - val_accuracy: 0.9938
# Epoch 645/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0199 - accuracy: 0.9969 - val_loss: 0.0396 - val_accuracy: 0.9907
# Epoch 646/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0316 - accuracy: 0.9921 - val_loss: 0.0336 - val_accuracy: 0.9860
# Epoch 647/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9959 - val_loss: 0.0271 - val_accuracy: 0.9907
# Epoch 648/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9973 - val_loss: 0.0363 - val_accuracy: 0.9922
# Epoch 649/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 0.9923 - val_loss: 0.1057 - val_accuracy: 0.9659
# Epoch 650/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 0.9885 - val_loss: 0.0347 - val_accuracy: 0.9922
# Epoch 651/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 0.9970 - val_loss: 0.0271 - val_accuracy: 0.9938
# Epoch 652/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 0.9976 - val_loss: 0.0302 - val_accuracy: 0.9922
# Epoch 653/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9971 - val_loss: 0.0311 - val_accuracy: 0.9907
# Epoch 654/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9949 - val_loss: 0.0317 - val_accuracy: 0.9922
# Epoch 655/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9963 - val_loss: 0.0294 - val_accuracy: 0.9938
# Epoch 656/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0295 - accuracy: 0.9950 - val_loss: 0.0286 - val_accuracy: 0.9907
# Epoch 657/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 0.9977 - val_loss: 0.0298 - val_accuracy: 0.9938
# Epoch 658/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0196 - accuracy: 0.9966 - val_loss: 0.0274 - val_accuracy: 0.9938
# Epoch 659/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 0.9903 - val_loss: 0.0885 - val_accuracy: 0.9767
# Epoch 660/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 0.9929 - val_loss: 0.0325 - val_accuracy: 0.9938
# Epoch 661/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.9945 - val_loss: 0.0572 - val_accuracy: 0.9845
# Epoch 662/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0309 - accuracy: 0.9938 - val_loss: 0.0380 - val_accuracy: 0.9907
# Epoch 663/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9954 - val_loss: 0.0499 - val_accuracy: 0.9891
# Epoch 664/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0231 - accuracy: 0.9972 - val_loss: 0.0415 - val_accuracy: 0.9860
# Epoch 665/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.9775 - val_loss: 0.0308 - val_accuracy: 0.9922
# Epoch 666/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.9965 - val_loss: 0.0243 - val_accuracy: 0.9953
# Epoch 667/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.9966 - val_loss: 0.0348 - val_accuracy: 0.9907
# Epoch 668/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 0.9970 - val_loss: 0.0277 - val_accuracy: 0.9938
# Epoch 669/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9953 - val_loss: 0.0368 - val_accuracy: 0.9907
# Epoch 670/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 0.9951 - val_loss: 0.0257 - val_accuracy: 0.9907
# Epoch 671/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.9983 - val_loss: 0.0289 - val_accuracy: 0.9891
# Epoch 672/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9975 - val_loss: 0.0264 - val_accuracy: 0.9922
# Epoch 673/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9977 - val_loss: 0.0554 - val_accuracy: 0.9752
# Epoch 674/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0324 - accuracy: 0.9928 - val_loss: 0.0276 - val_accuracy: 0.9938
# Epoch 675/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9982 - val_loss: 0.0254 - val_accuracy: 0.9922
# Epoch 676/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9984 - val_loss: 0.0298 - val_accuracy: 0.9907
# Epoch 677/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 0.9955 - val_loss: 0.0416 - val_accuracy: 0.9876
# Epoch 678/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9968 - val_loss: 0.0285 - val_accuracy: 0.9938
# Epoch 679/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 0.9974 - val_loss: 0.0265 - val_accuracy: 0.9938
# Epoch 680/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9970 - val_loss: 0.0333 - val_accuracy: 0.9938
# Epoch 681/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0232 - accuracy: 0.9952 - val_loss: 0.0410 - val_accuracy: 0.9907
# Epoch 682/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 0.9922 - val_loss: 0.0423 - val_accuracy: 0.9876
# Epoch 683/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 0.9971 - val_loss: 0.0578 - val_accuracy: 0.9845
# Epoch 684/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 0.9903 - val_loss: 0.0404 - val_accuracy: 0.9891
# Epoch 685/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9945 - val_loss: 0.0270 - val_accuracy: 0.9922
# Epoch 686/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9974 - val_loss: 0.0307 - val_accuracy: 0.9938
# Epoch 687/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9918 - val_loss: 0.0274 - val_accuracy: 0.9922
# Epoch 688/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9978 - val_loss: 0.0720 - val_accuracy: 0.9814
# Epoch 689/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 0.9935 - val_loss: 0.0332 - val_accuracy: 0.9891
# Epoch 690/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 0.9938 - val_loss: 0.0573 - val_accuracy: 0.9860
# Epoch 691/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0458 - accuracy: 0.9921 - val_loss: 0.0294 - val_accuracy: 0.9953
# Epoch 692/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9975 - val_loss: 0.0278 - val_accuracy: 0.9891
# Epoch 693/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 0.9963 - val_loss: 0.0263 - val_accuracy: 0.9922
# Epoch 694/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.9976 - val_loss: 0.0248 - val_accuracy: 0.9922
# Epoch 695/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9966 - val_loss: 0.0321 - val_accuracy: 0.9953
# Epoch 696/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 0.9964 - val_loss: 0.0268 - val_accuracy: 0.9938
# Epoch 697/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9981 - val_loss: 0.0288 - val_accuracy: 0.9922
# Epoch 698/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9978 - val_loss: 0.0379 - val_accuracy: 0.9922
# Epoch 699/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 0.9935 - val_loss: 0.0240 - val_accuracy: 0.9938
# Epoch 700/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9943 - val_loss: 0.0348 - val_accuracy: 0.9891
# Epoch 701/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9955 - val_loss: 0.1095 - val_accuracy: 0.9597
# Epoch 702/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0452 - accuracy: 0.9897 - val_loss: 0.0272 - val_accuracy: 0.9922
# Epoch 703/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.9979 - val_loss: 0.0226 - val_accuracy: 0.9938
# Epoch 704/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9981 - val_loss: 0.0266 - val_accuracy: 0.9938
# Epoch 705/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9965 - val_loss: 0.1899 - val_accuracy: 0.9628
# Epoch 706/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 0.9882 - val_loss: 0.0321 - val_accuracy: 0.9876
# Epoch 707/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9966 - val_loss: 0.0244 - val_accuracy: 0.9953
# Epoch 708/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 0.9978 - val_loss: 0.0272 - val_accuracy: 0.9938
# Epoch 709/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 0.9986 - val_loss: 0.0242 - val_accuracy: 0.9922
# Epoch 710/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.9980 - val_loss: 0.0329 - val_accuracy: 0.9922
# Epoch 711/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9967 - val_loss: 0.0310 - val_accuracy: 0.9907
# Epoch 712/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 0.9957 - val_loss: 0.0268 - val_accuracy: 0.9938
# Epoch 713/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 0.9969 - val_loss: 0.0259 - val_accuracy: 0.9969
# Epoch 714/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9972 - val_loss: 0.0490 - val_accuracy: 0.9798
# Epoch 715/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 0.9946 - val_loss: 0.0651 - val_accuracy: 0.9798
# Epoch 716/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9971 - val_loss: 0.0299 - val_accuracy: 0.9938
# Epoch 717/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9969 - val_loss: 0.0437 - val_accuracy: 0.9876
# Epoch 718/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 0.9951 - val_loss: 0.0278 - val_accuracy: 0.9953
# Epoch 719/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9964 - val_loss: 0.0292 - val_accuracy: 0.9891
# Epoch 720/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9961 - val_loss: 0.0674 - val_accuracy: 0.9860
# Epoch 721/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 0.9901 - val_loss: 0.0801 - val_accuracy: 0.9783
# Epoch 722/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9940 - val_loss: 0.0359 - val_accuracy: 0.9860
# Epoch 723/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9944 - val_loss: 0.0240 - val_accuracy: 0.9938
# Epoch 724/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9981 - val_loss: 0.0286 - val_accuracy: 0.9953
# Epoch 725/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0226 - accuracy: 0.9948 - val_loss: 0.0234 - val_accuracy: 0.9938
# Epoch 726/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9969 - val_loss: 0.0338 - val_accuracy: 0.9891
# Epoch 727/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9941 - val_loss: 0.0240 - val_accuracy: 0.9938
# Epoch 728/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9971 - val_loss: 0.0375 - val_accuracy: 0.9860
# Epoch 729/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9974 - val_loss: 0.0241 - val_accuracy: 0.9907
# Epoch 730/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.1036 - accuracy: 0.9760 - val_loss: 0.0555 - val_accuracy: 0.9829
# Epoch 731/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9933 - val_loss: 0.0312 - val_accuracy: 0.9907
# Epoch 732/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.9961 - val_loss: 0.0296 - val_accuracy: 0.9922
# Epoch 733/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 0.9961 - val_loss: 0.0258 - val_accuracy: 0.9938
# Epoch 734/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0171 - accuracy: 0.9976 - val_loss: 0.0281 - val_accuracy: 0.9891
# Epoch 735/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 0.9953 - val_loss: 0.0339 - val_accuracy: 0.9891
# Epoch 736/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9982 - val_loss: 0.0319 - val_accuracy: 0.9907
# Epoch 737/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0210 - accuracy: 0.9971 - val_loss: 0.0310 - val_accuracy: 0.9922
# Epoch 738/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0386 - accuracy: 0.9892 - val_loss: 0.0249 - val_accuracy: 0.9907
# Epoch 739/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.9984 - val_loss: 0.0228 - val_accuracy: 0.9922
# Epoch 740/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9973 - val_loss: 0.0274 - val_accuracy: 0.9922
# Epoch 741/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0390 - accuracy: 0.9927 - val_loss: 0.0225 - val_accuracy: 0.9922
# Epoch 742/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0152 - accuracy: 0.9982 - val_loss: 0.0263 - val_accuracy: 0.9938
# Epoch 743/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9954 - val_loss: 0.0228 - val_accuracy: 0.9938
# Epoch 744/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.9979 - val_loss: 0.0290 - val_accuracy: 0.9922
# Epoch 745/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9992 - val_loss: 0.0248 - val_accuracy: 0.9938
# Epoch 746/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9979 - val_loss: 0.0226 - val_accuracy: 0.9938
# Epoch 747/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0207 - accuracy: 0.9964 - val_loss: 0.0615 - val_accuracy: 0.9814
# Epoch 748/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 0.9938 - val_loss: 0.0333 - val_accuracy: 0.9922
# Epoch 749/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9914 - val_loss: 0.0337 - val_accuracy: 0.9907
# Epoch 750/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9972 - val_loss: 0.0264 - val_accuracy: 0.9922
# Epoch 751/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0191 - accuracy: 0.9972 - val_loss: 0.0439 - val_accuracy: 0.9876
# Epoch 752/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9977 - val_loss: 0.0265 - val_accuracy: 0.9922
# Epoch 753/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 0.9944 - val_loss: 0.0282 - val_accuracy: 0.9953
# Epoch 754/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9987 - val_loss: 0.0288 - val_accuracy: 0.9891
# Epoch 755/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0188 - accuracy: 0.9972 - val_loss: 0.0259 - val_accuracy: 0.9953
# Epoch 756/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 0.9939 - val_loss: 0.0373 - val_accuracy: 0.9891
# Epoch 757/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9951 - val_loss: 0.0367 - val_accuracy: 0.9907
# Epoch 758/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 0.9918 - val_loss: 0.0305 - val_accuracy: 0.9922
# Epoch 759/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 0.9993 - val_loss: 0.0234 - val_accuracy: 0.9953
# Epoch 760/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 0.9976 - val_loss: 0.0307 - val_accuracy: 0.9922
# Epoch 761/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9957 - val_loss: 0.0317 - val_accuracy: 0.9891
# Epoch 762/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.9966 - val_loss: 0.0280 - val_accuracy: 0.9922
# Epoch 763/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 0.9984 - val_loss: 0.0328 - val_accuracy: 0.9907
# Epoch 764/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9966 - val_loss: 0.0276 - val_accuracy: 0.9953
# Epoch 765/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9984 - val_loss: 0.0276 - val_accuracy: 0.9922
# Epoch 766/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9952 - val_loss: 0.0298 - val_accuracy: 0.9938
# Epoch 767/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9967 - val_loss: 0.0352 - val_accuracy: 0.9891
# Epoch 768/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 0.9950 - val_loss: 0.0555 - val_accuracy: 0.9783
# Epoch 769/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0381 - accuracy: 0.9921 - val_loss: 0.0266 - val_accuracy: 0.9891
# Epoch 770/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9987 - val_loss: 0.0253 - val_accuracy: 0.9922
# Epoch 771/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9978 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 772/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9992 - val_loss: 0.0295 - val_accuracy: 0.9907
# Epoch 773/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 0.9990 - val_loss: 0.0236 - val_accuracy: 0.9922
# Epoch 774/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 0.9904 - val_loss: 0.1665 - val_accuracy: 0.9674
# Epoch 775/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 0.9958 - val_loss: 0.0223 - val_accuracy: 0.9953
# Epoch 776/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0187 - accuracy: 0.9954 - val_loss: 0.0257 - val_accuracy: 0.9922
# Epoch 777/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9962 - val_loss: 0.0216 - val_accuracy: 0.9938
# Epoch 778/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9967 - val_loss: 0.0249 - val_accuracy: 0.9907
# Epoch 779/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.9973 - val_loss: 0.0202 - val_accuracy: 0.9969
# Epoch 780/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9981 - val_loss: 0.0437 - val_accuracy: 0.9876
# Epoch 781/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0486 - accuracy: 0.9884 - val_loss: 0.0246 - val_accuracy: 0.9922
# Epoch 782/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 0.9962 - val_loss: 0.0249 - val_accuracy: 0.9922
# Epoch 783/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9982 - val_loss: 0.0242 - val_accuracy: 0.9953
# Epoch 784/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 0.9996 - val_loss: 0.0217 - val_accuracy: 0.9938
# Epoch 785/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 0.9972 - val_loss: 0.0315 - val_accuracy: 0.9922
# Epoch 786/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0214 - accuracy: 0.9952 - val_loss: 0.0409 - val_accuracy: 0.9891
# Epoch 787/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.9981 - val_loss: 0.0210 - val_accuracy: 0.9953
# Epoch 788/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9975 - val_loss: 0.0216 - val_accuracy: 0.9938
# Epoch 789/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9980 - val_loss: 0.0257 - val_accuracy: 0.9922
# Epoch 790/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0134 - accuracy: 0.9983 - val_loss: 0.0275 - val_accuracy: 0.9922
# Epoch 791/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.9976 - val_loss: 0.0253 - val_accuracy: 0.9953
# Epoch 792/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9951 - val_loss: 0.1203 - val_accuracy: 0.9628
# Epoch 793/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0655 - accuracy: 0.9844 - val_loss: 0.0456 - val_accuracy: 0.9860
# Epoch 794/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0201 - accuracy: 0.9959 - val_loss: 0.0283 - val_accuracy: 0.9891
# Epoch 795/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0148 - accuracy: 0.9977 - val_loss: 0.0232 - val_accuracy: 0.9938
# Epoch 796/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 0.9980 - val_loss: 0.0252 - val_accuracy: 0.9907
# Epoch 797/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9982 - val_loss: 0.0265 - val_accuracy: 0.9907
# Epoch 798/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0125 - accuracy: 0.9986 - val_loss: 0.0228 - val_accuracy: 0.9922
# Epoch 799/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 0.9984 - val_loss: 0.0240 - val_accuracy: 0.9922
# Epoch 800/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9962 - val_loss: 0.0245 - val_accuracy: 0.9953
# Epoch 801/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9978 - val_loss: 0.0319 - val_accuracy: 0.9860
# Epoch 802/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0136 - accuracy: 0.9979 - val_loss: 0.0469 - val_accuracy: 0.9845
# Epoch 803/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 0.9952 - val_loss: 0.0341 - val_accuracy: 0.9907
# Epoch 804/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.9965 - val_loss: 0.0297 - val_accuracy: 0.9907
# Epoch 805/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.9969 - val_loss: 0.0558 - val_accuracy: 0.9845
# Epoch 806/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9934 - val_loss: 0.0281 - val_accuracy: 0.9907
# Epoch 807/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.9961 - val_loss: 0.0361 - val_accuracy: 0.9907
# Epoch 808/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9986 - val_loss: 0.0223 - val_accuracy: 0.9953
# Epoch 809/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0173 - accuracy: 0.9962 - val_loss: 0.0217 - val_accuracy: 0.9938
# Epoch 810/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9974 - val_loss: 0.0314 - val_accuracy: 0.9938
# Epoch 811/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0289 - accuracy: 0.9933 - val_loss: 0.0249 - val_accuracy: 0.9938
# Epoch 812/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9951 - val_loss: 0.0304 - val_accuracy: 0.9891
# Epoch 813/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9977 - val_loss: 0.0315 - val_accuracy: 0.9860
# Epoch 814/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9978 - val_loss: 0.0254 - val_accuracy: 0.9876
# Epoch 815/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 0.9977 - val_loss: 0.0273 - val_accuracy: 0.9922
# Epoch 816/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 0.9932 - val_loss: 0.0272 - val_accuracy: 0.9938
# Epoch 817/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9963 - val_loss: 0.0620 - val_accuracy: 0.9767
# Epoch 818/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 0.9943 - val_loss: 0.0239 - val_accuracy: 0.9938
# Epoch 819/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9974 - val_loss: 0.0219 - val_accuracy: 0.9953
# Epoch 820/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9985 - val_loss: 0.0243 - val_accuracy: 0.9938
# Epoch 821/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9967 - val_loss: 0.0247 - val_accuracy: 0.9922
# Epoch 822/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9960 - val_loss: 0.0507 - val_accuracy: 0.9891
# Epoch 823/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 0.9948 - val_loss: 0.0254 - val_accuracy: 0.9938
# Epoch 824/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9982 - val_loss: 0.0268 - val_accuracy: 0.9907
# Epoch 825/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9971 - val_loss: 0.0462 - val_accuracy: 0.9814
# Epoch 826/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9966 - val_loss: 0.0878 - val_accuracy: 0.9736
# Epoch 827/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9905 - val_loss: 0.0689 - val_accuracy: 0.9829
# Epoch 828/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 0.9937 - val_loss: 0.0290 - val_accuracy: 0.9907
# Epoch 829/3000
# ...
# Epoch 2895/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.5229e-04 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 0.9984
# Epoch 2896/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.5430e-04 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 0.9984
# Epoch 2897/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.3035e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9984
# Epoch 2898/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.8247e-04 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 0.9984
# Epoch 2899/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0047 - val_accuracy: 0.9984
# Epoch 2900/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.4572e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9984
# Epoch 2901/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.1849e-04 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9984
# Epoch 2902/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.8561e-04 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 0.9984
# Epoch 2903/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.6598e-04 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9984
# Epoch 2904/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.3345e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9984
# Epoch 2905/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.3947e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9984
# Epoch 2906/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.5308e-04 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9984
# Epoch 2907/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.9986 - val_loss: 0.0458 - val_accuracy: 0.9860
# Epoch 2908/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.0115 - val_accuracy: 0.9969
# Epoch 2909/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 0.9922
# Epoch 2910/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 0.9990 - val_loss: 0.0086 - val_accuracy: 0.9984
# Epoch 2911/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 9.5848e-04 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 0.9969
# Epoch 2912/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0281 - val_accuracy: 0.9953
# Epoch 2913/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0044 - val_accuracy: 0.9984
# Epoch 2914/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 8.8978e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 0.9984
# Epoch 2915/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.7772e-04 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 0.9984
# Epoch 2916/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.4225e-04 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 0.9984
# Epoch 2917/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.9993e-04 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 0.9984
# Epoch 2918/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 8.0547e-04 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 0.9984
# Epoch 2919/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.0959e-04 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 0.9969
# Epoch 2920/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.3145e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 2921/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.9972e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 0.9984
# Epoch 2922/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.2229e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9984
# Epoch 2923/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.9110e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 0.9984
# Epoch 2924/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.2547e-04 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9984
# Epoch 2925/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 5.9854e-04 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 0.9984
# Epoch 2926/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.6408e-04 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 0.9984
# Epoch 2927/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.7158e-04 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9953
# Epoch 2928/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.1556e-04 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9953
# Epoch 2929/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0263 - val_accuracy: 0.9907
# Epoch 2930/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0551 - accuracy: 0.9872 - val_loss: 0.0245 - val_accuracy: 0.9922
# Epoch 2931/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 0.9960 - val_loss: 0.0073 - val_accuracy: 0.9984
# Epoch 2932/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 9.7719e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9984
# Epoch 2933/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 8.2148e-04 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9984
# Epoch 2934/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.7216e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9984
# Epoch 2935/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.5674e-04 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9984
# Epoch 2936/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.1570e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9984
# Epoch 2937/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.4425e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9984
# Epoch 2938/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.5640e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9984
# Epoch 2939/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.3485e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9984
# Epoch 2940/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.1653e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 0.9984
# Epoch 2941/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.8632e-04 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 0.9984
# Epoch 2942/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 5.8454e-04 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 0.9984
# Epoch 2943/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.5547e-04 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 0.9984
# Epoch 2944/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 5.3811e-04 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 0.9984
# Epoch 2945/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.0010e-04 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 0.9984
# Epoch 2946/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9969
# Epoch 2947/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0518 - accuracy: 0.9919 - val_loss: 0.0753 - val_accuracy: 0.9814
# Epoch 2948/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 0.9992 - val_loss: 0.0088 - val_accuracy: 0.9984
# Epoch 2949/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9969
# Epoch 2950/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9984
# Epoch 2951/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 8.8425e-04 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9984
# Epoch 2952/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.6478e-04 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9984
# Epoch 2953/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.8610e-04 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9984
# Epoch 2954/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.4932e-04 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 0.9984
# Epoch 2955/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.3232e-04 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9984
# Epoch 2956/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.2580e-04 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9984
# Epoch 2957/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 8.7969e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9984
# Epoch 2958/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.3004e-04 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9984
# Epoch 2959/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.4931e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9984
# Epoch 2960/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.9006e-04 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9984
# Epoch 2961/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.8046e-04 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9984
# Epoch 2962/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0124 - accuracy: 0.9971 - val_loss: 0.1149 - val_accuracy: 0.9798
# Epoch 2963/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9836 - val_loss: 0.0092 - val_accuracy: 0.9984
# Epoch 2964/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9984
# Epoch 2965/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 8.0822e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9984
# Epoch 2966/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 8.3761e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9984
# Epoch 2967/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.6904e-04 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9984
# Epoch 2968/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.6673e-04 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9984
# Epoch 2969/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.6830e-04 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9984
# Epoch 2970/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.1468e-04 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9984
# Epoch 2971/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.1241e-04 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9984
# Epoch 2972/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.5704e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9984
# Epoch 2973/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.7331e-04 - accuracy: 1.0000 - val_loss: 0.0062 - val_accuracy: 0.9984
# Epoch 2974/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 5.8885e-04 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9984
# Epoch 2975/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.0861e-04 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9984
# Epoch 2976/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.3947e-04 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9984
# Epoch 2977/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.2545e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9984
# Epoch 2978/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 8.5715e-04 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9984
# Epoch 2979/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.1957e-04 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9984
# Epoch 2980/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 5.5451e-04 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 0.9984
# Epoch 2981/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.1410e-04 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 0.9984
# Epoch 2982/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.9185e-04 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 0.9984
# Epoch 2983/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.0918e-04 - accuracy: 1.0000 - val_loss: 0.0127 - val_accuracy: 0.9953
# Epoch 2984/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0590 - accuracy: 0.9878 - val_loss: 0.0357 - val_accuracy: 0.9860
# Epoch 2985/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9969 - val_loss: 0.0073 - val_accuracy: 0.9969
# Epoch 2986/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 9.9162e-04 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 0.9984
# Epoch 2987/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.2283e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9984
# Epoch 2988/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.9382e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9984
# Epoch 2989/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.1395e-04 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 0.9984
# Epoch 2990/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.5634e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9984
# Epoch 2991/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.6651e-04 - accuracy: 1.0000 - val_loss: 0.0050 - val_accuracy: 0.9984
# Epoch 2992/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.5055e-04 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 0.9984
# Epoch 2993/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 7.5572e-04 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9984
# Epoch 2994/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.4630e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9984
# Epoch 2995/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.5236e-04 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9984
# Epoch 2996/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.9128e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9984
# Epoch 2997/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.0351e-04 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 0.9984
# Epoch 2998/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 9.1149e-04 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 0.9984
# Epoch 2999/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.2290e-04 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 0.9984
# Epoch 3000/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 6.8083e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9984

# %% [markdown]
# ## GRAFICACIÓN DE RESULTADOS DE ENTRENAMIENTO

# %%
plt.figure(figsize=(16,6))
plt.grid()
len_epoch = len(history.history['accuracy'])
plt.plot(np.arange(0,len_epoch),history.history['accuracy'], label = 'accuracy',color=(0,0.81,0.8))
plt.plot(np.arange(0,len_epoch),history.history['val_accuracy'],label='val_accuracy',
         color=(1,0.6,0.45))
plt.legend()
plt.title('Precisión Entrenamiento',fontsize=14)
plt.xlabel('Epoca')
plt.ylabel('Precision')
plt.savefig(rs + '/04_ann_model/'+'execution_'+aux1+'_ann_results'+'/Precision_Entrenamiento.png')

plt.figure(figsize=(16,6))
plt.grid()
len_epoch = len(history.history['loss'])
plt.plot(np.arange(0,len_epoch),history.history['loss'], label = 'loss',color=(0,0.81,0.8))
plt.plot(np.arange(0,len_epoch),history.history['val_loss'],label='val_loss',color=(1,0.6,0.45))
plt.legend()
plt.title('Pérdida Entrenamiento',fontsize=14)
plt.xlabel('Epoca')
plt.ylabel('Perdida')
plt.savefig(rs + '/04_ann_model/' +'execution_'+aux1+'_ann_results' + '/Perdida_Entrenamiento.png')

# %% [markdown]
# ## EVALUACIÓN DE LA RED NEURONAL CON DATOS DE PRUEBA

# %%
corp_transf_test  = []

for i in x_test:
    aux  = [] 
    for j in i:
        aux.append(dict_pal_vec[j])
    prom = np.mean(np.array(aux),axis=0)
    corp_transf_test.append(list (prom))

corp_transf_test_np = np.array(corp_transf_test)

model.evaluate(corp_transf_test_np, np.array(y_test,dtype=int) - 1)
# Out:
# 51/51 [==============================] - 0s 912us/step - loss: 0.0115 - accuracy: 0.9957
# [0.011549178510904312, 0.9956575632095337]

# %% [markdown]
# Los valores de error y precisión entre el entrenamiento, validación y test son muy similares. Los errores presentan valores bajos y precisiones muy altas superiores al $99\%$ de manera que el clasificador tiene un alto rendimiento.
