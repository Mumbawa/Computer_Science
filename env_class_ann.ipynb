# %% [markdown]
# <center><h1><b>RED NEURONAL PARA LA CLASIFICACIÓN MORFOLÓGICA DE POZOS DE PETRÓLEO A PARTIR DE LA RESPUESTA DEL REGISTRO DE GAMMA RAY EMPLEANDO TÉCNICAS DE PROCESAMIENTO DE LENGUAJE NATURAL</b></h1></center>

# %% [markdown]
# # DEFINICIÓN DEL PROBLEMA

# %% [markdown]
# Un modelo geológico busca resolver tres preguntas ¿Qué rocas hay en el área?, ¿Cuál fue su ambiente de depósito?  Y ¿Qué geometría tienen las rocas en el área?, para responder a las dos primeras preguntas se podrían taladrar pozos extrayendo la roca intacta, pero al ser pozos de varios kilómetros de longitud esta solución es económicamente inviable.
#
# El método utilizado actualmente consiste en enviar una sonda con sensores de radiación gamma provenientes del Uranio, Torio y Potasio provenientes de las rocas. Esto permite clasificar las rocas en dos grupos: rocas arenosas (poco radioactivas) y rocas arcillosas (radioactivas).  A partir de los cambios en el tipo de roca a lo largo del pozo se identifican los diferentes **ambientes** de depósito.
#
# La interpretación del registro de rayos gamma esta sujeta del interprete en las definiciones de ¿Qué es una roca completamente arenosa?, ¿Qué es una roca completamente arcillosa?, ¿Cuáles son los limites de cada ambiente de depósito? Y ¿Cuál es la clasificación de cada ambiente?

# %% [markdown]
# # IMPORTACIÓN DE LIBRERIAS

# %%
import os
import sys
import math
import numpy             as np
import pandas            as pd
import random            as rd
import shutil            as sht
import tensorflow        as tf
import matplotlib.pyplot as plt
from   sklearn.decomposition       import PCA
from   sklearn.manifold            import TSNE
from   tensorflow.keras.optimizers import Adam
from   tensorflow.keras.models     import Model
from   tensorflow                  import keras
from   gensim.models               import word2vec
from   sklearn.decomposition       import KernelPCA
from   tensorflow.keras.utils      import plot_model
from   sklearn.model_selection     import train_test_split
from   tensorflow.keras.losses     import MeanSquaredError
from   tensorflow.keras.layers     import Input, Dense, Activation

# %% [markdown]
# # DEFINICIÓN DE FUNCIONES

# %%
#__________________________________________________________________________________________________

def Manejo_rutas (colab_o_local='local'):

    if colab_o_local == 'local':
        re = '../02_input'
        rs = '../03_output'
    elif colab_o_local == 'colab':

        from google.colab import drive
        drive.mount('/content/drive')

        re = '/content/drive/MyDrive/aux_diplomado/01_env_class_ann/02_input'
        rs = '/content/drive/MyDrive/aux_diplomado/01_env_class_ann/03_output'
    
    return re, rs
#__________________________________________________________________________________________________

def Borrar_result (rs):
        
    rutas =[rs + '/01_ambientes/todos_los_amb',
            rs + '/01_ambientes/amb_1',
            rs + '/01_ambientes/amb_2',
            rs + '/01_ambientes/amb_3',
            rs + '/01_ambientes/amb_4',
            rs + '/01_ambientes/amb_5',
            rs + '/01_ambientes/resumen_amb',
            rs + '/02_percentiles',
            rs + '/03_graficas/todos_los_amb',
            rs + '/03_graficas/amb_1',
            rs + '/03_graficas/amb_2',
            rs + '/03_graficas/amb_3',
            rs + '/03_graficas/amb_4',
            rs + '/03_graficas/amb_5']
    
    for i in rutas:
        aux = os.listdir(i)
        for j in aux:
            os.remove( i + '/' + j )
#__________________________________________________________________________________________________

def Df_amb (re, namb):
    with open (re + '/03_amb_pozos.txt', 'r') as fr:
        L_a_amb = [_.rstrip('\n').split(',') for _ in fr.readlines()]
        
    L_a_amb_dep = []
    for i in L_a_amb:
        if i != [''] and i[0][0] != '$':
            L_a_amb_dep.append( [ i[0], i[1].replace(' ',''), float(i[2]), float(i[3]) ])
            
    df_amb = pd.DataFrame(L_a_amb_dep, columns=['Pozo', 'Ambiente', 'Top', 'Bot'])

    if i == 1:
        return df_amb

    elif namb != 1:
        aux    = df_amb.groupby('Ambiente')
        df_amb = aux.sample(n=int (namb))
        return df_amb
#__________________________________________________________________________________________________

def GR_norm (GR, GR_inf, GR_sup):
    gr_nor = (GR-GR_inf) / (GR_sup-GR_inf)
    if gr_nor > 1.0:
        gr_nor = 1.0
    elif gr_nor < 0:
        gr_nor = 0.0
    return gr_nor
#__________________________________________________________________________________________________

def Zeros_fill (n_interv):
    
    if int (n_interv) <= 10:
        zeros_fill = int (1)
        return zeros_fill
    elif  10 < int (n_interv) <= 100:
        zeros_fill = int (2)
        return zeros_fill    
    elif  100 < int (n_interv) <= 1000:
        zeros_fill = int (3)
        return zeros_fill
    else:
        sys.exit('Error: El número de intervalos excede el valor permitido por la función'+
                  ' "Zeros_fill". Se debe modificar esta función para poder utilizar el número de'+
                  ' intervalos ingreasados.')
#__________________________________________________________________________________________________

def Codificacion (n_interv):

    lista_carct = []
    zeros_fill  = Zeros_fill(n_interv)
    
    for i in range (int(n_interv)):
        lista_carct.append('a' + str(i).zfill(zeros_fill))
    
    return lista_carct
#__________________________________________________________________________________________________

def Lista_interv (n_interv):
    
    len_interv  = 1 / n_interv
    list_interv = [] 
    codific     = Codificacion(n_interv)
    
    for i in range(int(n_interv)):
        if i == 0:
            interv = ( 0.0 , round(len_interv,8) , codific[i] )
            list_interv.append(interv)
            
        elif i < int(n_interv) - 1:
            interv=(round(list_interv[-1][1],8),round(list_interv[-1][1]+len_interv,8),\
                                                                            codific[i])
            list_interv.append(interv)
            
        elif i == int(n_interv) - 1:
            interv = ( round(list_interv[-1][1],8) , 1.0 , codific[i])
            list_interv.append(interv)
            
    return list_interv 
#__________________________________________________________________________________________________

def GRnorm_a_letra (GRnorm, list_interv):
    
    if np.isnan(GRnorm) == True:
        return np.nan                
    else:
        for i in range (len(list_interv)):
            if i <  len(list_interv) - 1:
                if GRnorm >= list_interv[i][0] and GRnorm < list_interv[i][1]:
                    return list_interv[i][2]                
            else:
                if GRnorm >= list_interv[i][0] and GRnorm <= list_interv[i][1]:
                    return list_interv[i][2]
#__________________________________________________________________________________________________

def Cent_no_cent (nom_pozo, conc,len_amb, Well_Df_Fil_Env):
    
    dept_i = Well_Df_Fil_Env['DEPT'].iloc[0]
    dept_j = Well_Df_Fil_Env['DEPT'].iloc[-1]
    
    ins_i = None
    ins_f = None
    
    if len(Well_Df_Fil_Env) >= len_amb:
        nramoi = True
    else:
        nramoi = False
        
    if conc == 1.0:
        
        if len(Well_Df_Fil_Env) > len_amb:
            aux1 = len(Well_Df_Fil_Env) - len_amb
            mod2 = round(aux1%2, 5)
            
            if mod2 == 0:
                aux2 = int(round(aux1/2,5))
                Well_Df_Fil_Env = Well_Df_Fil_Env.iloc[aux2:len(Well_Df_Fil_Env)-aux2].copy()
                ins_i = None
                ins_f = None
                
            if mod2!= 0:
                aux2 = round(aux1/2,5)
                aux3 = math.ceil(aux2)
                aux4 = aux3 - 1
                aux5 = [aux3,aux4]
                aux6 = rd.choice(aux5)
                aux5.remove(aux6)
                aux7 = aux5[0]
                Well_Df_Fil_Env = Well_Df_Fil_Env.iloc[aux6:len(Well_Df_Fil_Env)-aux7].copy()
                ins_i = None
                ins_f = None
                
        if len(Well_Df_Fil_Env) < len_amb:
            aux1 = abs(len(Well_Df_Fil_Env) - len_amb)
            mod2 = round(aux1%2, 5)
            
            if mod2 == 0:
                aux2 = int(round(aux1/2,5))
                aux3 = pd.Series(np.full(aux2, nom_pozo))
                aux4 = pd.Series(np.full(aux2, 0))
                aux5 = pd.concat([aux3,aux4,aux4,aux4,aux4], axis='columns')
                aux5.columns = ['WELLNAME','DEPT','GR','AMBIENTE','GR_NORM']
     
                Well_Df_Fil_Env = pd.concat([aux5,Well_Df_Fil_Env,aux5]).copy()
                
                ins_i = aux2
                ins_f = aux2
                
            if mod2!= 0:
                aux2  = round(aux1/2,5)
                aux3  = math.ceil(aux2)
                aux4  = aux3 - 1
                aux5  = [aux3,aux4]
                aux6  = rd.choice(aux5)
                aux5.remove(aux6)
                aux7  = aux5[0]
                
                aux8  = pd.Series(np.full(aux6, nom_pozo))
                aux9  = pd.Series(np.full(aux7, nom_pozo))
                
                aux10 = pd.Series(np.full(aux6, 0))
                aux11 = pd.Series(np.full(aux7, 0))
                
                aux12 = pd.concat([aux8,aux10,aux10,aux10,aux10], axis='columns')
                aux13 = pd.concat([aux9,aux11,aux11,aux11,aux11], axis='columns')
                
                aux12.columns = ['WELLNAME','DEPT','GR','AMBIENTE','GR_NORM']
                aux13.columns = ['WELLNAME','DEPT','GR','AMBIENTE','GR_NORM']
                
                Well_Df_Fil_Env = pd.concat([aux12,Well_Df_Fil_Env,aux13]).copy()
                
                ins_i = aux6
                ins_f = aux7
        
    return Well_Df_Fil_Env, nramoi, ins_i, ins_f, dept_i, dept_j
#__________________________________________________________________________________________________

def Graficar (nom_pozo, c_piso, dept_i, dept_j,ins_i,ins_f,nramoi,step, conc, len_env,
              env, l_cont, well_df_fil_amb, dmm,rs,g_graf):
    
    if g_graf == 1:
    
        nfgr=nom_pozo +'_niv_'+str(c_piso)+'_amb_'+env +'_'+str(l_cont[int(env)-1]).zfill(3)+'.png'
            
        if conc == 0.0:
            num_reg = len(well_df_fil_amb)
            plt.figure(figsize=(10./2.54,dmm/25.4 * num_reg), facecolor='whitesmoke')
            vec_prof    = well_df_fil_amb['DEPT']
            vec_GR_norm = well_df_fil_amb['GR_NORM']
            plt.ylim(well_df_fil_amb['DEPT'].iloc[0], well_df_fil_amb['DEPT'].iloc[-1])
            plt.fill_betweenx(vec_prof, vec_GR_norm, 0, zorder = 0, color ='silver')
            plt.fill_betweenx(vec_prof, vec_GR_norm, 1, zorder = 0, color = 'gold')
            
        elif conc == 1.0 and nramoi == True:
            plt.figure(figsize=(10./2.54,dmm/25.4 * len_env), facecolor='whitesmoke')
            vec_prof    = well_df_fil_amb['DEPT']
            vec_GR_norm = well_df_fil_amb['GR_NORM']
            plt.ylim(well_df_fil_amb['DEPT'].iloc[0], well_df_fil_amb['DEPT'].iloc[-1])
            plt.fill_betweenx(vec_prof, vec_GR_norm, 0, zorder = 0, color ='silver')
            plt.fill_betweenx(vec_prof, vec_GR_norm, 1, zorder = 0, color = 'gold')
            
        elif conc == 1.0 and nramoi == False:
            plt.figure(figsize=(10./2.54,dmm/25.4 * len_env), facecolor='whitesmoke')
            aux1  = step * ins_i
            aux2  = step * ins_f
            
            aux3 = dept_i - aux1
            aux4 = dept_j + aux2
            
            aux5 = [aux3  , dept_i] 
            aux6 = [dept_j, aux4]
            
            aux7 = [0,0]
            aux8 = [0,0]
            
            aux9 = well_df_fil_amb[(well_df_fil_amb['AMBIENTE']!=0) & (well_df_fil_amb['DEPT']!=0)]
            
            vec_prof    = aux5 + list(aux9['DEPT']) + aux6
            vec_GR_norm = aux7 + list(aux9['GR_NORM']) + aux8
            
            plt.ylim(aux3, aux4)
            plt.fill_betweenx(aux9['DEPT'], aux9['GR_NORM'], 0, zorder = 0, color ='silver')
            plt.fill_betweenx(aux9['DEPT'], aux9['GR_NORM'], 1, zorder = 0, color = 'gold')
            
        plt.plot(vec_GR_norm, vec_prof, linewidth=0.50, color='black')    
        plt.xlim(0,1)
        plt.gca().invert_yaxis()
        plt.grid()
        plt.title('PROF. VS G.R_norm\n(Pozo: {}, Nivel: {}, Amb.: {})'.format(nom_pozo,c_piso,env))
        plt.xlabel('GR_normalizado')
        plt.ylabel('Profundidad [ft]')
        plt.savefig(rs + '/03_graficas/todos_los_amb/'+nfgr, bbox_inches='tight',pad_inches=0.1)
        plt.close()
#__________________________________________________________________________________________________

def Gen_csv_amb (g_csv, well_df_fil_amb_cent_o_no,rs,nfile):
    if g_csv == 1:
        well_df_fil_amb_cent_o_no.to_csv(rs + '/01_ambientes/todos_los_amb/' + nfile, 
                                    index=False, columns=['DEPT','GR_NORM', 'CARACTER','AMBIENTE'])
#__________________________________________________________________________________________________

def Filt_top_bot (i,L_lin_ag_df, well_df, top, bot):
    
    if i < len(L_lin_ag_df) -1:
        filt = (well_df['DEPT'] >= top) & (well_df['DEPT'] < bot)
    else:
        filt = (well_df['DEPT'] >= top) & (well_df['DEPT'] <= bot)
        
    return filt
#__________________________________________________________________________________________________

def GR_qt_inf_sup (tg, well_df, nom_pozo):
    
    if tg == 0:
        GR_qt_inf = well_df['GR'].quantile(q_inf)
        GR_qt_sup = well_df['GR'].quantile(q_sup)
        return GR_qt_inf, GR_qt_sup
    
    if tg == 1:
        nom_pozo_aux = nom_pozo.split('_noi_')[0]
        GR_qt_inf    = df_tope.loc[nom_pozo_aux, 'Arena']
        GR_qt_sup    = df_tope.loc[nom_pozo_aux, 'Shale']
        return GR_qt_inf, GR_qt_sup
#__________________________________________________________________________________________________

def Guar_por_amb (rs,g_csv, g_graf):
    if g_csv == 1:
        ruta_csv = rs + '/01_ambientes/todos_los_amb'
        arch_csv = os.listdir(ruta_csv)
        for i in arch_csv:
            if 'amb_1' in i:
                sht.copyfile(ruta_csv + '/' +i, ruta_csv[:-13] + 'amb_1'+'/'+i)
            elif 'amb_2' in i:
                sht.copyfile(ruta_csv + '/' +i, ruta_csv[:-13] + 'amb_2'+'/'+i)
            elif 'amb_3' in i:
                sht.copyfile(ruta_csv + '/' +i, ruta_csv[:-13] + 'amb_3'+'/'+i)
            elif 'amb_4' in i:
                sht.copyfile(ruta_csv + '/' +i, ruta_csv[:-13] + 'amb_4'+'/'+i)
            elif 'amb_5' in i:
                sht.copyfile(ruta_csv + '/' +i, ruta_csv[:-13] + 'amb_5'+'/'+i)
    
    if g_graf == 1:
        ruta_grf = rs + '/03_graficas/todos_los_amb'
        arch_grf = os.listdir(ruta_grf)
        for i in arch_grf:
            if 'amb_1' in i:
                sht.copyfile(ruta_grf + '/' +i, ruta_grf[:-13] + 'amb_1'+'/'+i)
            elif 'amb_2' in i:
                sht.copyfile(ruta_grf + '/' +i, ruta_grf[:-13] + 'amb_2'+'/'+i)
            elif 'amb_3' in i:
                sht.copyfile(ruta_grf + '/' +i, ruta_grf[:-13] + 'amb_3'+'/'+i)
            elif 'amb_4' in i:
                sht.copyfile(ruta_grf + '/' +i, ruta_grf[:-13] + 'amb_4'+'/'+i)
            elif 'amb_5' in i:
                sht.copyfile(ruta_grf + '/' +i, ruta_grf[:-13] + 'amb_5'+'/'+i)
#__________________________________________________________________________________________________

def Read_ent_gen (re):
    ent_gen = list(np.loadtxt(re + '/01_dat_gen.txt', skiprows=2,usecols=0))
    ent_gen[0] = int(ent_gen[0])
    return ent_gen
#__________________________________________________________________________________________________

# %% [markdown]
# # PREPROCESAMIENTO DE DATOS

# %% [markdown]
# ## IMPLEMENTACIÓN DEL RUIDO GAUSSIANO

# %% [markdown]
# Ya que el proceso de obtención de mediciones de Gamma Ray (GR) en pozos de petróleos es bastante costoso para las empresas, no fue factible para el proceso de entrenamiento de la red tener una gran cantidad de muestras de forma gratuita.  Para solucionar esto se optó por generar gráficas de GR para el entrenamiento de manera artificial usuando ruidos gausianos a una magnitud que no modifique la clasificación asignada inicialmente al ambiente.
#
# La siguiente imagen ilustra la idea anterior:
#
# ![picture](https://drive.google.com/uc?export=view&id=1o2HG36rgjIFLdZ2ZzKgm9yNg5_94xrnb)
#
# En la anterior imagen, la gráfica izquierda corresponde al registro original, mientras que la derecha tiene aplicado el ruido gaussiano.
#
# Para el proceso de entrenamiento se generaron $25$ registros con ruido gaussiano por cada registro original.

# %%
#__________________________________________________________________________________________________

re, rs = Manejo_rutas (colab_o_local='colab')

Borrar_result(rs)

n,factor, quant,namb, conc,g_csv,g_graf,len_env,tg,q_inf,q_sup,step,n_interv,dmm=Read_ent_gen (re)

df_amb       = Df_amb(re,namb)
L_nom_pozos  = list (df_amb['Pozo'].unique())

df  = pd.read_csv(re + '/02_data_set_well_logs.csv', usecols=[5,17,20])[['WELLNAME','DEPT','GR']]
df.set_index('WELLNAME',inplace=True)
df           = df.loc[L_nom_pozos].reset_index()
well_grp_df_rg  = df.groupby('WELLNAME', sort=False)
#__________________________________________________________________________________________________

for nom_pozo in L_nom_pozos:
    
    well_df = well_grp_df_rg.get_group(nom_pozo).copy().reset_index(drop=True)
    GR_quant = well_df['GR'].quantile(quant)
    
    for i in range(n):
        
        well_df_noise = well_df.copy()
        well_df_noise['GR'] = well_df_noise['GR'].apply\
            (lambda x: x + np.random.normal()*factor*GR_quant)
            
        well_df_noise['WELLNAME'] = nom_pozo + '_noi_' + str(i+1)
        
        df = df.append(well_df_noise,ignore_index=True)
#__________________________________________________________________________________________________
        
well_grp_df_amb  = df_amb.groupby('Pozo', sort=False)
for i in well_grp_df_amb:
    for j in range(n):
        df_noi_ij = i[1].copy()
        df_noi_ij['Pozo'] = i[0] + '_noi_' + str (j+1)
        df_amb = df_amb.append(df_noi_ij,ignore_index=True)
#__________________________________________________________________________________________________
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## OBTENCIÓN DEL CORPUS

# %% [markdown]
# Uno de los principales problemas de este estudio proviene del hecho de que cada medición de Gamma Ray (GR) para un pozo tiene una cantidad de registros altamente variable y por lo tanto los ambientes serán considerablemente variables en longitud. Para trabajar con estos conjuntos de longitudes desiguales se decidió abordar el problema como un problema de ***procesamiento del lenguaje natural***.
#
# Ya que el rango de los datos permanece entre $[0,1]$ se dividió el intervalo en 100 subintervalos de $0.01$ y se le asignó a cada uno de los intervalos las palabras desde $a00$ hasta $a99$ siendo así cada ambiente un documento de texto.
#
# Para el presente estudio se tokenizó cada documento por palabras, de forma que el corpus del análisis se constituye por el conjunto de palabras $\{a00,...,a99\}$.
#
# El siguente esquema ilustra lo anterior:
#
# ![picture](https://drive.google.com/uc?export=view&id=1CsaculFAU3FpdOifSu6wOqP6BnbhL4xt)

# %%
#__________________________________________________________________________________________________

list_interv = Lista_interv(n_interv)

df['DEPT']  = (df['DEPT']/0.3048).round(8)    
well_grp_df = df.groupby('WELLNAME')

well_grp_df_amb  = df_amb.groupby('Pozo', sort=False)

df_tope =  pd.read_csv(re + '/04_bases_arena_shale.csv',
                        dtype={'Arena':float, 'Shale':float}).set_index('Pozo')
#__________________________________________________________________________________________________

l_perc     = []
l_cont     = [0,0,0,0,0]
l_resm_env = []
corpus     = []
label_amb  = []

for amb_pozo in well_grp_df_amb:

    nom_pozo    = amb_pozo[0]
    L_lin_ag_df = amb_pozo[1].drop('Pozo', axis='columns')
    L_lin_ag_df['Ambiente'] = L_lin_ag_df['Ambiente'].astype(str)

    #______________________________________________________________________________________________
    
    well_df   = well_grp_df.get_group(nom_pozo).copy().reset_index(drop=True)
    
    GR_min    = well_df['GR'].min()
    GR_max    = well_df['GR'].max()
    GR_qt_inf, GR_qt_sup = GR_qt_inf_sup (tg, well_df, nom_pozo)
    #______________________________________________________________________________________________
    
    c_piso = 0
    for i in range(len(L_lin_ag_df)):
        
        c_piso += 1
        
        env  = L_lin_ag_df.iloc[i,0]
        top  = L_lin_ag_df.iloc[i,1]
        bot  = L_lin_ag_df.iloc[i,2]
        
        filt = Filt_top_bot (i,L_lin_ag_df, well_df, top, bot)
            
        well_df_fil_amb = well_df[filt].copy()
        
        well_df_fil_amb['AMBIENTE'] = env
        well_df_fil_amb['GR_NORM']  = well_df_fil_amb['GR'].apply(GR_norm, 
                                                            args=(GR_qt_inf,GR_qt_sup))
        
        well_df_fil_amb_cent_o_no,nramoi,ins_i,ins_f,dept_i, dept_j =Cent_no_cent(nom_pozo,conc,
                                                                        len_env,well_df_fil_amb)
                                                  
        well_df_fil_amb_cent_o_no['CARACTER'] = well_df_fil_amb_cent_o_no['GR_NORM'].apply\
                                                              (GRnorm_a_letra, args=(list_interv,))
        
        corpus.append(list (well_df_fil_amb_cent_o_no['CARACTER']))
        label_amb.append(env)        
        
        l_cont[int(env)-1] = l_cont[int(env)-1] + 1                                          
        
        Graficar(nom_pozo, c_piso,dept_i, dept_j,ins_i,ins_f,nramoi, step, conc, len_env, env,
                                                    l_cont,well_df_fil_amb_cent_o_no,dmm,rs,g_graf)     
                    
        nfile=nom_pozo+'_niv_'+str(c_piso)+'_amb_'+env +'_'+str(l_cont[int(env)-1]).zfill(3)+'.csv'
        
        Gen_csv_amb (g_csv, well_df_fil_amb_cent_o_no,rs,nfile)
        
        l_resm_env.append([nfile[:-4],int(env),nom_pozo,c_piso,top,bot])
#__________________________________________________________________________________________________

resm_df = pd.DataFrame(l_resm_env,columns=['Nombre_amb','Ambiente','Pozo','Nivel', 'Top','Bot']) 
if g_csv == 1:                                                            
    resm_df.to_csv(rs + '/01_ambientes/resumen_amb/Resumen_ambientes.csv',index=False)

perc_df = pd.DataFrame(l_perc,columns=['POZO','GR_MIN','GR_MAX','GR_PER_5','GR_PER_95'])  
if g_csv == 1:                                                            
    perc_df.to_csv(rs + '/02_percentiles/GR_perc_pozos.csv',index=False)

Guar_por_amb(rs,g_csv, g_graf)
#__________________________________________________________________________________________________

# %% [markdown]
# ## DEPURACIÓN DEL CORPUS - ELIMINACIÓN DE VALORES nan

# %% [markdown]
# Dado que la sonda que se envía para tomar los registros de Gamma Ray puede dejar de tomar registros en ciertos puntos por diversos problemas que se puedan presentar (por ejemplo: se derrumba las paredes de la performación lo cual afecta el equipo), en algunos pozos con los que trabajó no se tiene registro de Gamma Ray en cierto rango de profundidades. Para solucionar este incoveniente de valores faltantes, se optó por suprimir estos registros. El siguiente esquema ilustra lo anterior:
#
# ![picture](https://drive.google.com/uc?export=view&id=1bD2st1u1XXtoJdzBBaaagS8Pvh7SqqYI)

# %%
corpus_s_nan = []
for i in corpus:
    corpus_s_nan.append(list (pd.Series(i).dropna()))

# %% [markdown]
# ## DEFINICIÓN DEL CONJUNTO DE DATOS DE ENTRENAMIENTO Y PRUEBA

# %%
random_state = 60
x_train, x_test, y_train, y_test = train_test_split(corpus_s_nan, label_amb, test_size=0.20,
                                                                  random_state=random_state)

# %% [markdown]
# ## TRANSFORMACIÓN DE LOS ELEMENTOS DEL CORPUS (TEXTO A VECTORES) EMPLEANDO Word2Vec

# %% [markdown]
# Como función de embedding se utilizó *word2vec* con el fin de transformar cada palabra en un vector de $10$ entradas y posteriormente obtener un vector representativo (también de $10$ entradas) de cada documento por medio de promediar cada conjunto de vectores que lo conforman.
#
# Una ventaja importante del método recien descrito, es que al final todos los registros (que inicialmente tenían longitudes variables) van a tener la misma longitud ($10$), lo cual facilita la construcción de la red neuronal, pues la capa de entrada será siempre de $10$ neuronas (como se verá más adelnate).
#
# La siquiente gráfica ilustra lo anterior:
#
# ![picture](https://drive.google.com/uc?export=view&id=10flF5HKgNdjXEIOWHqalIDA_p-H7FEt3)
#
# Se decidió utilizar una ventana de contexto de 100 palabras con el fin de recoger en longitud física un total de 30 metros, que según nuestro experto es en promedio las distancias en las que se presentan cambios importantes en los pozos.

# %%
feature_size   = 10
window_context = 100                        
min_word_count = 1
sample         = 1e-3

w2v_model = word2vec.Word2Vec(x_train, window=window_context, 
                              min_count=min_word_count, sample=sample, size=feature_size)
                          
wvs = w2v_model.wv[Codificacion (n_interv)]

dict_pal_vec = dict (zip(Codificacion (n_interv) ,  wvs))

corp_transf_train  = []

for i in x_train:
    aux  = [] 
    for j in i:
        aux.append(dict_pal_vec[j])
    prom = np.mean(np.array(aux),axis=0)
    corp_transf_train.append(list (prom))

corp_transf_train_np = np.array(corp_transf_train)

# %% [markdown]
# # RED NEURONAL

# %% [markdown]
# ## DEFINICIÓN DE LA ARQUITECTURA DE LA RED NEURONAL

# %% [markdown]
# El problema en sí es un problema básico de clasificación, una vez obtenidos los tensores representativos de cada documento de tamaño estándar se procede a alimentar una red con una capa de entrada de 10 neuronas y dos capaz densas de 20 y 10 neuronas con activación relu y una capa de salida softmax con 5 neuronas las cuales representan las 5 clases de ambientes.

# %%
# Construcción del modelo

model = keras.models.Sequential([
 keras.layers.Input(shape=[10,]),
 keras.layers.Dense(20, activation="relu"),
 keras.layers.Dense(10, activation="relu"),
 keras.layers.Dense(5 , activation="softmax")
])

# Parámetros del modelo

model.compile(loss = 'sparse_categorical_crossentropy',
              optimizer = 'adam',
              metrics = 'accuracy')

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 20)                220
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 55
# =================================================================
# Total params: 485
# Trainable params: 485
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## ENTRENAMIENTO DE LA RED NEURONAL

# %%
history = model.fit(corp_transf_train_np, np.array(y_train,dtype=int) - 1, epochs = 3000, 
                                                                   validation_split=0.1)

# En esta parte se guarda el modelo
aux = os.listdir(rs + '/04_ann_model')
aux1 = str (len(aux)+1).zfill(2)
model.save(rs + '/04_ann_model/' +'execution_'+aux1+'_ann_results' + '/ann_model.h5')
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 501/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0581 - accuracy: 0.9790 - val_loss: 0.0614 - val_accuracy: 0.9767
# Epoch 502/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0695 - accuracy: 0.9741 - val_loss: 0.1570 - val_accuracy: 0.9535
# Epoch 503/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0743 - accuracy: 0.9767 - val_loss: 0.0709 - val_accuracy: 0.9783
# Epoch 504/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0600 - accuracy: 0.9815 - val_loss: 0.0653 - val_accuracy: 0.9752
# Epoch 505/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 0.9812 - val_loss: 0.0632 - val_accuracy: 0.9798
# Epoch 506/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 0.9778 - val_loss: 0.0585 - val_accuracy: 0.9798
# Epoch 507/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0571 - accuracy: 0.9809 - val_loss: 0.0838 - val_accuracy: 0.9690
# Epoch 508/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0640 - accuracy: 0.9782 - val_loss: 0.0716 - val_accuracy: 0.9798
# Epoch 509/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0962 - accuracy: 0.9728 - val_loss: 0.0682 - val_accuracy: 0.9767
# Epoch 510/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0643 - accuracy: 0.9799 - val_loss: 0.0646 - val_accuracy: 0.9752
# Epoch 511/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0541 - accuracy: 0.9812 - val_loss: 0.0668 - val_accuracy: 0.9767
# Epoch 512/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9851 - val_loss: 0.0673 - val_accuracy: 0.9829
# Epoch 513/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0763 - accuracy: 0.9747 - val_loss: 0.0792 - val_accuracy: 0.9736
# Epoch 514/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0568 - accuracy: 0.9818 - val_loss: 0.0807 - val_accuracy: 0.9674
# Epoch 515/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9828 - val_loss: 0.0660 - val_accuracy: 0.9798
# Epoch 516/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0512 - accuracy: 0.9850 - val_loss: 0.0846 - val_accuracy: 0.9752
# Epoch 517/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0551 - accuracy: 0.9818 - val_loss: 0.0685 - val_accuracy: 0.9860
# Epoch 518/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 0.9794 - val_loss: 0.0653 - val_accuracy: 0.9814
# Epoch 519/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0507 - accuracy: 0.9838 - val_loss: 0.0600 - val_accuracy: 0.9798
# Epoch 520/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0612 - accuracy: 0.9808 - val_loss: 0.0660 - val_accuracy: 0.9783
# Epoch 521/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9837 - val_loss: 0.0831 - val_accuracy: 0.9705
# Epoch 522/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 0.9854 - val_loss: 0.0643 - val_accuracy: 0.9798
# Epoch 523/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0633 - accuracy: 0.9770 - val_loss: 0.0637 - val_accuracy: 0.9829
# Epoch 524/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9785 - val_loss: 0.0656 - val_accuracy: 0.9798
# Epoch 525/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0489 - accuracy: 0.9853 - val_loss: 0.0580 - val_accuracy: 0.9845
# Epoch 526/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9855 - val_loss: 0.0610 - val_accuracy: 0.9814
# Epoch 527/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0579 - accuracy: 0.9815 - val_loss: 0.0607 - val_accuracy: 0.9814
# Epoch 528/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9840 - val_loss: 0.0599 - val_accuracy: 0.9829
# Epoch 529/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0544 - accuracy: 0.9847 - val_loss: 0.0632 - val_accuracy: 0.9798
# Epoch 530/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0555 - accuracy: 0.9847 - val_loss: 0.0649 - val_accuracy: 0.9814
# Epoch 531/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 0.9890 - val_loss: 0.0580 - val_accuracy: 0.9860
# Epoch 532/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0573 - accuracy: 0.9817 - val_loss: 0.0721 - val_accuracy: 0.9752
# Epoch 533/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 0.9878 - val_loss: 0.0612 - val_accuracy: 0.9814
# Epoch 534/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 0.9865 - val_loss: 0.0580 - val_accuracy: 0.9814
# Epoch 535/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0502 - accuracy: 0.9869 - val_loss: 0.0626 - val_accuracy: 0.9767
# Epoch 536/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0702 - accuracy: 0.9778 - val_loss: 0.0694 - val_accuracy: 0.9798
# Epoch 537/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0535 - accuracy: 0.9868 - val_loss: 0.0611 - val_accuracy: 0.9814
# Epoch 538/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 0.9885 - val_loss: 0.0561 - val_accuracy: 0.9860
# Epoch 539/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0556 - accuracy: 0.9859 - val_loss: 0.0597 - val_accuracy: 0.9814
# Epoch 540/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 0.9875 - val_loss: 0.0552 - val_accuracy: 0.9829
# Epoch 541/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0451 - accuracy: 0.9887 - val_loss: 0.0632 - val_accuracy: 0.9814
# Epoch 542/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9847 - val_loss: 0.0817 - val_accuracy: 0.9752
# Epoch 543/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0771 - accuracy: 0.9801 - val_loss: 0.1267 - val_accuracy: 0.9783
# Epoch 544/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 0.9798 - val_loss: 0.0669 - val_accuracy: 0.9721
# Epoch 545/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9850 - val_loss: 0.0622 - val_accuracy: 0.9814
# Epoch 546/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 0.9858 - val_loss: 0.0678 - val_accuracy: 0.9752
# Epoch 547/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0453 - accuracy: 0.9896 - val_loss: 0.0620 - val_accuracy: 0.9767
# Epoch 548/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0509 - accuracy: 0.9854 - val_loss: 0.0573 - val_accuracy: 0.9860
# Epoch 549/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0554 - accuracy: 0.9855 - val_loss: 0.0638 - val_accuracy: 0.9829
# Epoch 550/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0578 - accuracy: 0.9845 - val_loss: 0.0643 - val_accuracy: 0.9814
# Epoch 551/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0502 - accuracy: 0.9856 - val_loss: 0.0737 - val_accuracy: 0.9752
# Epoch 552/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0530 - accuracy: 0.9863 - val_loss: 0.0557 - val_accuracy: 0.9829
# Epoch 553/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9828 - val_loss: 0.0560 - val_accuracy: 0.9845
# Epoch 554/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0482 - accuracy: 0.9878 - val_loss: 0.0594 - val_accuracy: 0.9845
# Epoch 555/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0516 - accuracy: 0.9857 - val_loss: 0.0718 - val_accuracy: 0.9767
# Epoch 556/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0514 - accuracy: 0.9867 - val_loss: 0.0548 - val_accuracy: 0.9860
# Epoch 557/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0496 - accuracy: 0.9878 - val_loss: 0.0555 - val_accuracy: 0.9860
# Epoch 558/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 0.9909 - val_loss: 0.0572 - val_accuracy: 0.9829
# Epoch 559/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0770 - accuracy: 0.9773 - val_loss: 0.0656 - val_accuracy: 0.9752
# Epoch 560/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0578 - accuracy: 0.9820 - val_loss: 0.0572 - val_accuracy: 0.9798
# Epoch 561/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0464 - accuracy: 0.9881 - val_loss: 0.0667 - val_accuracy: 0.9752
# Epoch 562/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0522 - accuracy: 0.9849 - val_loss: 0.0645 - val_accuracy: 0.9814
# Epoch 563/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0500 - accuracy: 0.9871 - val_loss: 0.0625 - val_accuracy: 0.9829
# Epoch 564/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0749 - accuracy: 0.9785 - val_loss: 0.0588 - val_accuracy: 0.9845
# Epoch 565/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0480 - accuracy: 0.9867 - val_loss: 0.0533 - val_accuracy: 0.9845
# Epoch 566/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 0.9859 - val_loss: 0.0594 - val_accuracy: 0.9814
# Epoch 567/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0505 - accuracy: 0.9847 - val_loss: 0.0657 - val_accuracy: 0.9845
# Epoch 568/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9798 - val_loss: 0.0540 - val_accuracy: 0.9829
# Epoch 569/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 0.9895 - val_loss: 0.0559 - val_accuracy: 0.9814
# Epoch 570/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0596 - accuracy: 0.9823 - val_loss: 0.0598 - val_accuracy: 0.9814
# Epoch 571/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0458 - accuracy: 0.9865 - val_loss: 0.0578 - val_accuracy: 0.9860
# Epoch 572/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0471 - accuracy: 0.9875 - val_loss: 0.0825 - val_accuracy: 0.9736
# Epoch 573/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0446 - accuracy: 0.9891 - val_loss: 0.0558 - val_accuracy: 0.9891
# Epoch 574/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0472 - accuracy: 0.9869 - val_loss: 0.0637 - val_accuracy: 0.9814
# Epoch 575/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0480 - accuracy: 0.9880 - val_loss: 0.0589 - val_accuracy: 0.9814
# Epoch 576/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0479 - accuracy: 0.9873 - val_loss: 0.0642 - val_accuracy: 0.9814
# Epoch 577/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0469 - accuracy: 0.9877 - val_loss: 0.0864 - val_accuracy: 0.9690
# Epoch 578/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0589 - accuracy: 0.9837 - val_loss: 0.0515 - val_accuracy: 0.9860
# Epoch 579/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 0.9836 - val_loss: 0.0675 - val_accuracy: 0.9721
# Epoch 580/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9854 - val_loss: 0.0592 - val_accuracy: 0.9783
# Epoch 581/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 0.9840 - val_loss: 0.0602 - val_accuracy: 0.9860
# Epoch 582/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0506 - accuracy: 0.9869 - val_loss: 0.0518 - val_accuracy: 0.9860
# Epoch 583/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0464 - accuracy: 0.9851 - val_loss: 0.0478 - val_accuracy: 0.9829
# Epoch 584/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9886 - val_loss: 0.0500 - val_accuracy: 0.9876
# Epoch 585/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0512 - accuracy: 0.9858 - val_loss: 0.0555 - val_accuracy: 0.9845
# Epoch 586/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9895 - val_loss: 0.0536 - val_accuracy: 0.9814
# Epoch 587/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0431 - accuracy: 0.9887 - val_loss: 0.0586 - val_accuracy: 0.9829
# Epoch 588/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 0.9881 - val_loss: 0.0572 - val_accuracy: 0.9860
# Epoch 589/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0704 - accuracy: 0.9819 - val_loss: 0.0696 - val_accuracy: 0.9798
# Epoch 590/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9807 - val_loss: 0.0574 - val_accuracy: 0.9783
# Epoch 591/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0544 - accuracy: 0.9846 - val_loss: 0.0513 - val_accuracy: 0.9845
# Epoch 592/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0502 - accuracy: 0.9861 - val_loss: 0.0549 - val_accuracy: 0.9829
# Epoch 593/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0480 - accuracy: 0.9854 - val_loss: 0.0486 - val_accuracy: 0.9860
# Epoch 594/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9862 - val_loss: 0.0492 - val_accuracy: 0.9891
# Epoch 595/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0433 - accuracy: 0.9893 - val_loss: 0.0485 - val_accuracy: 0.9891
# Epoch 596/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0447 - accuracy: 0.9878 - val_loss: 0.0661 - val_accuracy: 0.9845
# Epoch 597/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0481 - accuracy: 0.9885 - val_loss: 0.0494 - val_accuracy: 0.9876
# Epoch 598/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 0.9860 - val_loss: 0.0480 - val_accuracy: 0.9876
# Epoch 599/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0521 - accuracy: 0.9843 - val_loss: 0.0478 - val_accuracy: 0.9876
# Epoch 600/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 0.9879 - val_loss: 0.0592 - val_accuracy: 0.9829
# Epoch 601/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 0.9871 - val_loss: 0.0579 - val_accuracy: 0.9752
# Epoch 602/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 0.9875 - val_loss: 0.0718 - val_accuracy: 0.9736
# Epoch 603/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 0.9851 - val_loss: 0.0654 - val_accuracy: 0.9767
# Epoch 604/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0440 - accuracy: 0.9884 - val_loss: 0.0603 - val_accuracy: 0.9798
# Epoch 605/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0444 - accuracy: 0.9871 - val_loss: 0.0545 - val_accuracy: 0.9860
# Epoch 606/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0548 - accuracy: 0.9846 - val_loss: 0.0539 - val_accuracy: 0.9814
# Epoch 607/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 0.9881 - val_loss: 0.0597 - val_accuracy: 0.9814
# Epoch 608/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 0.9905 - val_loss: 0.0541 - val_accuracy: 0.9845
# Epoch 609/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0439 - accuracy: 0.9891 - val_loss: 0.0604 - val_accuracy: 0.9814
# Epoch 610/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9876 - val_loss: 0.0508 - val_accuracy: 0.9860
# Epoch 611/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0557 - accuracy: 0.9836 - val_loss: 0.0594 - val_accuracy: 0.9860
# Epoch 612/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0710 - accuracy: 0.9760 - val_loss: 0.0531 - val_accuracy: 0.9845
# Epoch 613/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9882 - val_loss: 0.0582 - val_accuracy: 0.9860
# Epoch 614/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 0.9904 - val_loss: 0.0496 - val_accuracy: 0.9860
# Epoch 615/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0604 - accuracy: 0.9848 - val_loss: 0.0496 - val_accuracy: 0.9845
# Epoch 616/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9902 - val_loss: 0.0717 - val_accuracy: 0.9783
# Epoch 617/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0461 - accuracy: 0.9882 - val_loss: 0.0494 - val_accuracy: 0.9860
# Epoch 618/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9910 - val_loss: 0.0540 - val_accuracy: 0.9845
# Epoch 619/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0425 - accuracy: 0.9883 - val_loss: 0.0482 - val_accuracy: 0.9860
# Epoch 620/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0398 - accuracy: 0.9903 - val_loss: 0.0523 - val_accuracy: 0.9860
# Epoch 621/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 0.9910 - val_loss: 0.0575 - val_accuracy: 0.9845
# Epoch 622/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 0.9876 - val_loss: 0.0506 - val_accuracy: 0.9876
# Epoch 623/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 0.9893 - val_loss: 0.0554 - val_accuracy: 0.9814
# Epoch 624/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0543 - accuracy: 0.9841 - val_loss: 0.0627 - val_accuracy: 0.9767
# Epoch 625/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 0.9873 - val_loss: 0.0520 - val_accuracy: 0.9860
# Epoch 626/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 0.9904 - val_loss: 0.0495 - val_accuracy: 0.9860
# Epoch 627/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9857 - val_loss: 0.0502 - val_accuracy: 0.9876
# Epoch 628/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0381 - accuracy: 0.9899 - val_loss: 0.0539 - val_accuracy: 0.9860
# Epoch 629/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 0.9893 - val_loss: 0.0467 - val_accuracy: 0.9876
# Epoch 630/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0493 - accuracy: 0.9875 - val_loss: 0.1756 - val_accuracy: 0.9736
# Epoch 631/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0784 - accuracy: 0.9852 - val_loss: 0.0541 - val_accuracy: 0.9845
# Epoch 632/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9860 - val_loss: 0.0499 - val_accuracy: 0.9876
# Epoch 633/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9829 - val_loss: 0.0592 - val_accuracy: 0.9783
# Epoch 634/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0502 - accuracy: 0.9838 - val_loss: 0.0483 - val_accuracy: 0.9876
# Epoch 635/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0430 - accuracy: 0.9888 - val_loss: 0.0574 - val_accuracy: 0.9814
# Epoch 636/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9872 - val_loss: 0.0451 - val_accuracy: 0.9876
# Epoch 637/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 0.9887 - val_loss: 0.0516 - val_accuracy: 0.9814
# Epoch 638/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9874 - val_loss: 0.0675 - val_accuracy: 0.9736
# Epoch 639/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0506 - accuracy: 0.9864 - val_loss: 0.0519 - val_accuracy: 0.9860
# Epoch 640/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0444 - accuracy: 0.9872 - val_loss: 0.0483 - val_accuracy: 0.9860
# Epoch 641/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 0.9875 - val_loss: 0.0465 - val_accuracy: 0.9860
# Epoch 642/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0469 - accuracy: 0.9876 - val_loss: 0.0571 - val_accuracy: 0.9845
# Epoch 643/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0534 - accuracy: 0.9855 - val_loss: 0.0507 - val_accuracy: 0.9845
# Epoch 644/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0390 - accuracy: 0.9886 - val_loss: 0.0486 - val_accuracy: 0.9860
# Epoch 645/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 0.9905 - val_loss: 0.0471 - val_accuracy: 0.9876
# Epoch 646/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0378 - accuracy: 0.9905 - val_loss: 0.0761 - val_accuracy: 0.9721
# Epoch 647/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0417 - accuracy: 0.9883 - val_loss: 0.0494 - val_accuracy: 0.9845
# Epoch 648/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9859 - val_loss: 0.0490 - val_accuracy: 0.9876
# Epoch 649/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0409 - accuracy: 0.9900 - val_loss: 0.0655 - val_accuracy: 0.9783
# Epoch 650/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0491 - accuracy: 0.9861 - val_loss: 0.0537 - val_accuracy: 0.9829
# Epoch 651/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0439 - accuracy: 0.9861 - val_loss: 0.0485 - val_accuracy: 0.9876
# Epoch 652/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0416 - accuracy: 0.9893 - val_loss: 0.0536 - val_accuracy: 0.9829
# Epoch 653/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 0.9918 - val_loss: 0.0510 - val_accuracy: 0.9829
# Epoch 654/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9807 - val_loss: 0.0600 - val_accuracy: 0.9798
# Epoch 655/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0514 - accuracy: 0.9841 - val_loss: 0.0514 - val_accuracy: 0.9876
# Epoch 656/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0442 - accuracy: 0.9869 - val_loss: 0.0578 - val_accuracy: 0.9814
# Epoch 657/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0472 - accuracy: 0.9864 - val_loss: 0.0539 - val_accuracy: 0.9814
# Epoch 658/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0466 - accuracy: 0.9872 - val_loss: 0.0487 - val_accuracy: 0.9829
# Epoch 659/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9893 - val_loss: 0.0577 - val_accuracy: 0.9783
# Epoch 660/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0484 - accuracy: 0.9850 - val_loss: 0.0457 - val_accuracy: 0.9860
# Epoch 661/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0434 - accuracy: 0.9862 - val_loss: 0.0474 - val_accuracy: 0.9860
# Epoch 662/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0390 - accuracy: 0.9885 - val_loss: 0.0477 - val_accuracy: 0.9860
# Epoch 663/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 0.9882 - val_loss: 0.1087 - val_accuracy: 0.9674
# Epoch 664/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0561 - accuracy: 0.9837 - val_loss: 0.0489 - val_accuracy: 0.9829
# Epoch 665/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 0.9900 - val_loss: 0.0470 - val_accuracy: 0.9860
# Epoch 666/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9877 - val_loss: 0.0505 - val_accuracy: 0.9860
# Epoch 667/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 0.9880 - val_loss: 0.1362 - val_accuracy: 0.9690
# Epoch 668/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0674 - accuracy: 0.9838 - val_loss: 0.0457 - val_accuracy: 0.9876
# Epoch 669/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9889 - val_loss: 0.0518 - val_accuracy: 0.9860
# Epoch 670/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9886 - val_loss: 0.0449 - val_accuracy: 0.9845
# Epoch 671/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 0.9898 - val_loss: 0.0661 - val_accuracy: 0.9721
# Epoch 672/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 0.9844 - val_loss: 0.0454 - val_accuracy: 0.9891
# Epoch 673/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0469 - accuracy: 0.9866 - val_loss: 0.0468 - val_accuracy: 0.9876
# Epoch 674/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0480 - accuracy: 0.9851 - val_loss: 0.0441 - val_accuracy: 0.9876
# Epoch 675/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 0.9903 - val_loss: 0.0633 - val_accuracy: 0.9814
# Epoch 676/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0477 - accuracy: 0.9849 - val_loss: 0.0537 - val_accuracy: 0.9798
# Epoch 677/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0420 - accuracy: 0.9876 - val_loss: 0.0477 - val_accuracy: 0.9876
# Epoch 678/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 0.9871 - val_loss: 0.0511 - val_accuracy: 0.9876
# Epoch 679/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9872 - val_loss: 0.0531 - val_accuracy: 0.9845
# Epoch 680/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0405 - accuracy: 0.9880 - val_loss: 0.0526 - val_accuracy: 0.9860
# Epoch 681/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0529 - accuracy: 0.9825 - val_loss: 0.0488 - val_accuracy: 0.9845
# Epoch 682/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0475 - accuracy: 0.9853 - val_loss: 0.0502 - val_accuracy: 0.9860
# Epoch 683/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9907 - val_loss: 0.0438 - val_accuracy: 0.9876
# Epoch 684/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9862 - val_loss: 0.0492 - val_accuracy: 0.9845
# Epoch 685/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0355 - accuracy: 0.9910 - val_loss: 0.0436 - val_accuracy: 0.9860
# Epoch 686/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9921 - val_loss: 0.0505 - val_accuracy: 0.9860
# Epoch 687/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0441 - accuracy: 0.9872 - val_loss: 0.0419 - val_accuracy: 0.9891
# Epoch 688/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 0.9884 - val_loss: 0.0560 - val_accuracy: 0.9829
# Epoch 689/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0397 - accuracy: 0.9896 - val_loss: 0.0480 - val_accuracy: 0.9845
# Epoch 690/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0370 - accuracy: 0.9911 - val_loss: 0.0775 - val_accuracy: 0.9721
# Epoch 691/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0482 - accuracy: 0.9857 - val_loss: 0.0491 - val_accuracy: 0.9860
# Epoch 692/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0447 - accuracy: 0.9862 - val_loss: 0.0472 - val_accuracy: 0.9876
# Epoch 693/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9903 - val_loss: 0.0519 - val_accuracy: 0.9814
# Epoch 694/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9885 - val_loss: 0.0461 - val_accuracy: 0.9860
# Epoch 695/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0483 - accuracy: 0.9860 - val_loss: 0.0750 - val_accuracy: 0.9721
# Epoch 696/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0545 - accuracy: 0.9832 - val_loss: 0.0478 - val_accuracy: 0.9860
# Epoch 697/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9916 - val_loss: 0.0416 - val_accuracy: 0.9891
# Epoch 698/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9873 - val_loss: 0.0455 - val_accuracy: 0.9845
# Epoch 699/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0392 - accuracy: 0.9884 - val_loss: 0.0497 - val_accuracy: 0.9829
# Epoch 700/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0519 - accuracy: 0.9871 - val_loss: 0.0686 - val_accuracy: 0.9767
# Epoch 701/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0397 - accuracy: 0.9886 - val_loss: 0.0458 - val_accuracy: 0.9876
# Epoch 702/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0386 - accuracy: 0.9906 - val_loss: 0.0459 - val_accuracy: 0.9876
# Epoch 703/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0498 - accuracy: 0.9846 - val_loss: 0.0500 - val_accuracy: 0.9845
# Epoch 704/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0343 - accuracy: 0.9905 - val_loss: 0.0461 - val_accuracy: 0.9860
# Epoch 705/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9894 - val_loss: 0.0460 - val_accuracy: 0.9876
# Epoch 706/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0439 - accuracy: 0.9885 - val_loss: 0.0595 - val_accuracy: 0.9829
# Epoch 707/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0462 - accuracy: 0.9875 - val_loss: 0.0525 - val_accuracy: 0.9860
# Epoch 708/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0416 - accuracy: 0.9879 - val_loss: 0.0464 - val_accuracy: 0.9876
# Epoch 709/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0385 - accuracy: 0.9887 - val_loss: 0.0443 - val_accuracy: 0.9876
# Epoch 710/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9876 - val_loss: 0.0450 - val_accuracy: 0.9876
# Epoch 711/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0405 - accuracy: 0.9871 - val_loss: 0.0600 - val_accuracy: 0.9783
# Epoch 712/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0436 - accuracy: 0.9885 - val_loss: 0.0591 - val_accuracy: 0.9798
# Epoch 713/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9879 - val_loss: 0.0456 - val_accuracy: 0.9876
# Epoch 714/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 0.9892 - val_loss: 0.0511 - val_accuracy: 0.9845
# Epoch 715/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 0.9882 - val_loss: 0.0496 - val_accuracy: 0.9829
# Epoch 716/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9902 - val_loss: 0.0407 - val_accuracy: 0.9891
# Epoch 717/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0445 - accuracy: 0.9867 - val_loss: 0.0431 - val_accuracy: 0.9860
# Epoch 718/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0398 - accuracy: 0.9879 - val_loss: 0.0570 - val_accuracy: 0.9783
# Epoch 719/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 0.9911 - val_loss: 0.0595 - val_accuracy: 0.9783
# Epoch 720/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9902 - val_loss: 0.0465 - val_accuracy: 0.9876
# Epoch 721/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0399 - accuracy: 0.9898 - val_loss: 0.0512 - val_accuracy: 0.9829
# Epoch 722/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0401 - accuracy: 0.9889 - val_loss: 0.0404 - val_accuracy: 0.9860
# Epoch 723/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 0.9894 - val_loss: 0.0436 - val_accuracy: 0.9845
# Epoch 724/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 0.9900 - val_loss: 0.0590 - val_accuracy: 0.9736
# Epoch 725/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 0.9881 - val_loss: 0.0411 - val_accuracy: 0.9891
# Epoch 726/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 0.9836 - val_loss: 0.0412 - val_accuracy: 0.9876
# Epoch 727/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 0.9902 - val_loss: 0.0436 - val_accuracy: 0.9860
# Epoch 728/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9908 - val_loss: 0.0410 - val_accuracy: 0.9891
# Epoch 729/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0398 - accuracy: 0.9891 - val_loss: 0.0561 - val_accuracy: 0.9736
# Epoch 730/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 0.9888 - val_loss: 0.0492 - val_accuracy: 0.9860
# Epoch 731/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 0.9845 - val_loss: 0.0583 - val_accuracy: 0.9814
# Epoch 732/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9887 - val_loss: 0.0393 - val_accuracy: 0.9891
# Epoch 733/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0349 - accuracy: 0.9900 - val_loss: 0.0509 - val_accuracy: 0.9860
# Epoch 734/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9899 - val_loss: 0.0448 - val_accuracy: 0.9876
# Epoch 735/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0402 - accuracy: 0.9876 - val_loss: 0.0411 - val_accuracy: 0.9891
# Epoch 736/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0403 - accuracy: 0.9879 - val_loss: 0.0504 - val_accuracy: 0.9860
# Epoch 737/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0484 - accuracy: 0.9866 - val_loss: 0.0443 - val_accuracy: 0.9876
# Epoch 738/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0399 - accuracy: 0.9878 - val_loss: 0.0509 - val_accuracy: 0.9798
# Epoch 739/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9908 - val_loss: 0.0434 - val_accuracy: 0.9860
# Epoch 740/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 0.9874 - val_loss: 0.0423 - val_accuracy: 0.9876
# Epoch 741/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9912 - val_loss: 0.0519 - val_accuracy: 0.9829
# Epoch 742/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0373 - accuracy: 0.9895 - val_loss: 0.0573 - val_accuracy: 0.9752
# Epoch 743/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 0.9883 - val_loss: 0.0415 - val_accuracy: 0.9860
# Epoch 744/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 0.9913 - val_loss: 0.0481 - val_accuracy: 0.9860
# Epoch 745/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9860 - val_loss: 0.0482 - val_accuracy: 0.9845
# Epoch 746/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0497 - accuracy: 0.9848 - val_loss: 0.0473 - val_accuracy: 0.9860
# Epoch 747/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9889 - val_loss: 0.0468 - val_accuracy: 0.9845
# Epoch 748/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 0.9867 - val_loss: 0.0460 - val_accuracy: 0.9876
# Epoch 749/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 0.9898 - val_loss: 0.0535 - val_accuracy: 0.9814
# Epoch 750/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0501 - accuracy: 0.9846 - val_loss: 0.1257 - val_accuracy: 0.9798
# Epoch 751/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0548 - accuracy: 0.9823 - val_loss: 0.0456 - val_accuracy: 0.9876
# Epoch 752/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0367 - accuracy: 0.9897 - val_loss: 0.0447 - val_accuracy: 0.9876
# Epoch 753/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0365 - accuracy: 0.9897 - val_loss: 0.0631 - val_accuracy: 0.9690
# Epoch 754/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 0.9902 - val_loss: 0.0471 - val_accuracy: 0.9860
# Epoch 755/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9880 - val_loss: 0.0443 - val_accuracy: 0.9860
# Epoch 756/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9883 - val_loss: 0.0443 - val_accuracy: 0.9876
# Epoch 757/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9886 - val_loss: 0.0420 - val_accuracy: 0.9891
# Epoch 758/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0536 - accuracy: 0.9826 - val_loss: 0.0485 - val_accuracy: 0.9845
# Epoch 759/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0376 - accuracy: 0.9887 - val_loss: 0.0444 - val_accuracy: 0.9845
# Epoch 760/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9901 - val_loss: 0.0389 - val_accuracy: 0.9876
# Epoch 761/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 0.9881 - val_loss: 0.1197 - val_accuracy: 0.9659
# Epoch 762/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 0.9820 - val_loss: 0.0466 - val_accuracy: 0.9829
# Epoch 763/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0379 - accuracy: 0.9891 - val_loss: 0.0449 - val_accuracy: 0.9845
# Epoch 764/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 0.9901 - val_loss: 0.0494 - val_accuracy: 0.9814
# Epoch 765/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0451 - accuracy: 0.9849 - val_loss: 0.0629 - val_accuracy: 0.9736
# Epoch 766/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9885 - val_loss: 0.0677 - val_accuracy: 0.9736
# Epoch 767/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0447 - accuracy: 0.9872 - val_loss: 0.0875 - val_accuracy: 0.9721
# Epoch 768/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0341 - accuracy: 0.9901 - val_loss: 0.0437 - val_accuracy: 0.9860
# Epoch 769/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0412 - accuracy: 0.9854 - val_loss: 0.0415 - val_accuracy: 0.9891
# Epoch 770/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9915 - val_loss: 0.0526 - val_accuracy: 0.9860
# Epoch 771/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0433 - accuracy: 0.9878 - val_loss: 0.0495 - val_accuracy: 0.9845
# Epoch 772/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0386 - accuracy: 0.9889 - val_loss: 0.0569 - val_accuracy: 0.9767
# Epoch 773/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0488 - accuracy: 0.9842 - val_loss: 0.0425 - val_accuracy: 0.9876
# Epoch 774/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0337 - accuracy: 0.9908 - val_loss: 0.0421 - val_accuracy: 0.9891
# Epoch 775/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9912 - val_loss: 0.0858 - val_accuracy: 0.9721
# Epoch 776/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 0.9898 - val_loss: 0.0425 - val_accuracy: 0.9876
# Epoch 777/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0411 - accuracy: 0.9861 - val_loss: 0.0543 - val_accuracy: 0.9783
# Epoch 778/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 0.9871 - val_loss: 0.0399 - val_accuracy: 0.9876
# Epoch 779/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9906 - val_loss: 0.0552 - val_accuracy: 0.9829
# Epoch 780/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 0.9906 - val_loss: 0.0534 - val_accuracy: 0.9783
# Epoch 781/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9869 - val_loss: 0.0411 - val_accuracy: 0.9860
# Epoch 782/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9915 - val_loss: 0.0411 - val_accuracy: 0.9876
# Epoch 783/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0316 - accuracy: 0.9924 - val_loss: 0.0417 - val_accuracy: 0.9876
# Epoch 784/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0360 - accuracy: 0.9892 - val_loss: 0.0418 - val_accuracy: 0.9860
# Epoch 785/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 0.9900 - val_loss: 0.0411 - val_accuracy: 0.9891
# Epoch 786/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0356 - accuracy: 0.9885 - val_loss: 0.0388 - val_accuracy: 0.9845
# Epoch 787/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0359 - accuracy: 0.9893 - val_loss: 0.0631 - val_accuracy: 0.9767
# Epoch 788/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0479 - accuracy: 0.9844 - val_loss: 0.0687 - val_accuracy: 0.9814
# Epoch 789/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0546 - accuracy: 0.9809 - val_loss: 0.0454 - val_accuracy: 0.9829
# Epoch 790/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0395 - accuracy: 0.9860 - val_loss: 0.0426 - val_accuracy: 0.9860
# Epoch 791/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 0.9897 - val_loss: 0.0432 - val_accuracy: 0.9876
# Epoch 792/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0390 - accuracy: 0.9893 - val_loss: 0.0409 - val_accuracy: 0.9876
# Epoch 793/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0285 - accuracy: 0.9928 - val_loss: 0.0403 - val_accuracy: 0.9907
# Epoch 794/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0331 - accuracy: 0.9913 - val_loss: 0.0405 - val_accuracy: 0.9876
# Epoch 795/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 0.9896 - val_loss: 0.0462 - val_accuracy: 0.9814
# Epoch 796/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9844 - val_loss: 0.0665 - val_accuracy: 0.9814
# Epoch 797/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 0.9886 - val_loss: 0.0431 - val_accuracy: 0.9891
# Epoch 798/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0328 - accuracy: 0.9905 - val_loss: 0.0438 - val_accuracy: 0.9860
# Epoch 799/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0373 - accuracy: 0.9875 - val_loss: 0.0442 - val_accuracy: 0.9845
# Epoch 800/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0582 - accuracy: 0.9845 - val_loss: 0.0462 - val_accuracy: 0.9876
# Epoch 801/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0346 - accuracy: 0.9906 - val_loss: 0.0492 - val_accuracy: 0.9814
# Epoch 802/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0394 - accuracy: 0.9873 - val_loss: 0.0374 - val_accuracy: 0.9891
# Epoch 803/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0319 - accuracy: 0.9905 - val_loss: 0.0381 - val_accuracy: 0.9891
# Epoch 804/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9883 - val_loss: 0.0592 - val_accuracy: 0.9767
# Epoch 805/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 0.9853 - val_loss: 0.0425 - val_accuracy: 0.9876
# Epoch 806/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9924 - val_loss: 0.0482 - val_accuracy: 0.9845
# Epoch 807/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0344 - accuracy: 0.9903 - val_loss: 0.0465 - val_accuracy: 0.9876
# Epoch 808/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9906 - val_loss: 0.0383 - val_accuracy: 0.9876
# Epoch 809/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0341 - accuracy: 0.9893 - val_loss: 0.0424 - val_accuracy: 0.9876
# Epoch 810/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0308 - accuracy: 0.9918 - val_loss: 0.0424 - val_accuracy: 0.9845
# Epoch 811/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 0.9915 - val_loss: 0.0434 - val_accuracy: 0.9876
# Epoch 812/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0453 - accuracy: 0.9839 - val_loss: 0.0517 - val_accuracy: 0.9845
# Epoch 813/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9883 - val_loss: 0.0407 - val_accuracy: 0.9860
# Epoch 814/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0299 - accuracy: 0.9921 - val_loss: 0.0483 - val_accuracy: 0.9814
# Epoch 815/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9929 - val_loss: 0.0806 - val_accuracy: 0.9736
# Epoch 816/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0537 - accuracy: 0.9841 - val_loss: 0.0689 - val_accuracy: 0.9814
# Epoch 817/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0413 - accuracy: 0.9871 - val_loss: 0.0444 - val_accuracy: 0.9829
# Epoch 818/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0451 - accuracy: 0.9871 - val_loss: 0.0392 - val_accuracy: 0.9860
# Epoch 819/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 0.9890 - val_loss: 0.0417 - val_accuracy: 0.9860
# Epoch 820/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 0.9833 - val_loss: 0.0424 - val_accuracy: 0.9845
# Epoch 821/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9896 - val_loss: 0.0389 - val_accuracy: 0.9876
# Epoch 822/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 0.9923 - val_loss: 0.0482 - val_accuracy: 0.9783
# Epoch 823/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 0.9883 - val_loss: 0.0380 - val_accuracy: 0.9876
# Epoch 824/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0334 - accuracy: 0.9896 - val_loss: 0.0388 - val_accuracy: 0.9876
# Epoch 825/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0340 - accuracy: 0.9894 - val_loss: 0.0439 - val_accuracy: 0.9891
# Epoch 826/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0302 - accuracy: 0.9924 - val_loss: 0.0453 - val_accuracy: 0.9876
# Epoch 827/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9888 - val_loss: 0.0386 - val_accuracy: 0.9845
# Epoch 828/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0383 - accuracy: 0.9885 - val_loss: 0.0453 - val_accuracy: 0.9829
# Epoch 829/3000
# ...
# Epoch 2893/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 0.9966 - val_loss: 0.0308 - val_accuracy: 0.9876
# Epoch 2894/3000
# 182/182 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 0.9949 - val_loss: 0.0188 - val_accuracy: 0.9876
# Epoch 2895/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 0.9951 - val_loss: 0.0172 - val_accuracy: 0.9891
# Epoch 2896/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9968 - val_loss: 0.0207 - val_accuracy: 0.9891
# Epoch 2897/3000
# 182/182 [==============================] - 1s 3ms/step - loss: 0.0064 - accuracy: 0.9971 - val_loss: 0.0174 - val_accuracy: 0.9922
# Epoch 2898/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9959 - val_loss: 0.0175 - val_accuracy: 0.9907
# Epoch 2899/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 0.9968 - val_loss: 0.0187 - val_accuracy: 0.9922
# Epoch 2900/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9966 - val_loss: 0.0214 - val_accuracy: 0.9907
# Epoch 2901/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9970 - val_loss: 0.0176 - val_accuracy: 0.9907
# Epoch 2902/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.9969 - val_loss: 0.0209 - val_accuracy: 0.9891
# Epoch 2903/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 0.9970 - val_loss: 0.0177 - val_accuracy: 0.9907
# Epoch 2904/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.0165 - val_accuracy: 0.9891
# Epoch 2905/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9965 - val_loss: 0.0183 - val_accuracy: 0.9922
# Epoch 2906/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.9939 - val_loss: 0.0266 - val_accuracy: 0.9876
# Epoch 2907/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9900 - val_loss: 0.0287 - val_accuracy: 0.9891
# Epoch 2908/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 0.9902 - val_loss: 0.0194 - val_accuracy: 0.9907
# Epoch 2909/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0189 - val_accuracy: 0.9891
# Epoch 2910/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.9971 - val_loss: 0.0202 - val_accuracy: 0.9907
# Epoch 2911/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9973 - val_loss: 0.0204 - val_accuracy: 0.9891
# Epoch 2912/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 0.9960 - val_loss: 0.0294 - val_accuracy: 0.9814
# Epoch 2913/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9971 - val_loss: 0.0541 - val_accuracy: 0.9860
# Epoch 2914/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0220 - accuracy: 0.9915 - val_loss: 0.0256 - val_accuracy: 0.9907
# Epoch 2915/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9965 - val_loss: 0.0181 - val_accuracy: 0.9922
# Epoch 2916/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9956 - val_loss: 0.0172 - val_accuracy: 0.9907
# Epoch 2917/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0187 - val_accuracy: 0.9891
# Epoch 2918/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9962 - val_loss: 0.0170 - val_accuracy: 0.9922
# Epoch 2919/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9959 - val_loss: 0.0391 - val_accuracy: 0.9814
# Epoch 2920/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0342 - accuracy: 0.9889 - val_loss: 0.0221 - val_accuracy: 0.9891
# Epoch 2921/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9930 - val_loss: 0.0221 - val_accuracy: 0.9876
# Epoch 2922/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9962 - val_loss: 0.0231 - val_accuracy: 0.9907
# Epoch 2923/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.9964 - val_loss: 0.0243 - val_accuracy: 0.9907
# Epoch 2924/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0176 - val_accuracy: 0.9922
# Epoch 2925/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 0.9973 - val_loss: 0.0180 - val_accuracy: 0.9907
# Epoch 2926/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9960 - val_loss: 0.0174 - val_accuracy: 0.9907
# Epoch 2927/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 0.9957 - val_loss: 0.0200 - val_accuracy: 0.9907
# Epoch 2928/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.9956 - val_loss: 0.0202 - val_accuracy: 0.9891
# Epoch 2929/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9967 - val_loss: 0.0188 - val_accuracy: 0.9907
# Epoch 2930/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.9968 - val_loss: 0.0184 - val_accuracy: 0.9907
# Epoch 2931/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 0.9957 - val_loss: 0.0200 - val_accuracy: 0.9922
# Epoch 2932/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0197 - accuracy: 0.9905 - val_loss: 0.3916 - val_accuracy: 0.9643
# Epoch 2933/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0739 - accuracy: 0.9881 - val_loss: 0.0276 - val_accuracy: 0.9876
# Epoch 2934/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.9952 - val_loss: 0.0241 - val_accuracy: 0.9891
# Epoch 2935/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9959 - val_loss: 0.0205 - val_accuracy: 0.9907
# Epoch 2936/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.9966 - val_loss: 0.0224 - val_accuracy: 0.9891
# Epoch 2937/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0183 - val_accuracy: 0.9907
# Epoch 2938/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9970 - val_loss: 0.0197 - val_accuracy: 0.9922
# Epoch 2939/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9974 - val_loss: 0.0171 - val_accuracy: 0.9922
# Epoch 2940/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 0.9971 - val_loss: 0.0176 - val_accuracy: 0.9922
# Epoch 2941/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.9971 - val_loss: 0.0178 - val_accuracy: 0.9922
# Epoch 2942/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 0.9964 - val_loss: 0.0194 - val_accuracy: 0.9922
# Epoch 2943/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 0.9975 - val_loss: 0.0171 - val_accuracy: 0.9907
# Epoch 2944/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0243 - val_accuracy: 0.9845
# Epoch 2945/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0244 - val_accuracy: 0.9891
# Epoch 2946/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0220 - val_accuracy: 0.9891
# Epoch 2947/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9963 - val_loss: 0.0165 - val_accuracy: 0.9891
# Epoch 2948/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 0.9973 - val_loss: 0.0169 - val_accuracy: 0.9891
# Epoch 2949/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 0.9977 - val_loss: 0.0156 - val_accuracy: 0.9922
# Epoch 2950/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 0.9964 - val_loss: 0.2247 - val_accuracy: 0.9597
# Epoch 2951/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0860 - accuracy: 0.9781 - val_loss: 0.0513 - val_accuracy: 0.9829
# Epoch 2952/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9923 - val_loss: 0.0222 - val_accuracy: 0.9876
# Epoch 2953/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.9965 - val_loss: 0.0242 - val_accuracy: 0.9876
# Epoch 2954/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9972 - val_loss: 0.0191 - val_accuracy: 0.9891
# Epoch 2955/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0059 - accuracy: 0.9970 - val_loss: 0.0192 - val_accuracy: 0.9907
# Epoch 2956/3000
# 182/182 [==============================] - 0s 3ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.0198 - val_accuracy: 0.9891
# Epoch 2957/3000
# 182/182 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 0.9969 - val_loss: 0.0185 - val_accuracy: 0.9907
# Epoch 2958/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9971 - val_loss: 0.0278 - val_accuracy: 0.9798
# Epoch 2959/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0139 - accuracy: 0.9938 - val_loss: 0.0177 - val_accuracy: 0.9891
# Epoch 2960/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.9961 - val_loss: 0.0203 - val_accuracy: 0.9907
# Epoch 2961/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9963 - val_loss: 0.0178 - val_accuracy: 0.9907
# Epoch 2962/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9967 - val_loss: 0.0168 - val_accuracy: 0.9891
# Epoch 2963/3000
# 182/182 [==============================] - 0s 3ms/step - loss: 0.0083 - accuracy: 0.9964 - val_loss: 0.0191 - val_accuracy: 0.9891
# Epoch 2964/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9961 - val_loss: 0.0174 - val_accuracy: 0.9891
# Epoch 2965/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9920 - val_loss: 0.0290 - val_accuracy: 0.9891
# Epoch 2966/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9913 - val_loss: 0.0167 - val_accuracy: 0.9922
# Epoch 2967/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 0.9938 - val_loss: 0.0650 - val_accuracy: 0.9783
# Epoch 2968/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9893 - val_loss: 0.0226 - val_accuracy: 0.9891
# Epoch 2969/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9969 - val_loss: 0.0207 - val_accuracy: 0.9876
# Epoch 2970/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 0.9964 - val_loss: 0.0225 - val_accuracy: 0.9891
# Epoch 2971/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0224 - val_accuracy: 0.9891
# Epoch 2972/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 0.9976 - val_loss: 0.0231 - val_accuracy: 0.9891
# Epoch 2973/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0196 - val_accuracy: 0.9907
# Epoch 2974/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9964 - val_loss: 0.0225 - val_accuracy: 0.9876
# Epoch 2975/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9968 - val_loss: 0.0215 - val_accuracy: 0.9860
# Epoch 2976/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 0.9965 - val_loss: 0.0213 - val_accuracy: 0.9876
# Epoch 2977/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9962 - val_loss: 0.0256 - val_accuracy: 0.9876
# Epoch 2978/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9926 - val_loss: 0.0583 - val_accuracy: 0.9860
# Epoch 2979/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0257 - accuracy: 0.9921 - val_loss: 0.0221 - val_accuracy: 0.9876
# Epoch 2980/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 0.9939 - val_loss: 0.0269 - val_accuracy: 0.9860
# Epoch 2981/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9958 - val_loss: 0.0292 - val_accuracy: 0.9860
# Epoch 2982/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.9965 - val_loss: 0.0225 - val_accuracy: 0.9891
# Epoch 2983/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0095 - accuracy: 0.9945 - val_loss: 0.0280 - val_accuracy: 0.9876
# Epoch 2984/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 0.9965 - val_loss: 0.0220 - val_accuracy: 0.9891
# Epoch 2985/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9963 - val_loss: 0.0229 - val_accuracy: 0.9907
# Epoch 2986/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 0.9956 - val_loss: 0.0385 - val_accuracy: 0.9798
# Epoch 2987/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0873 - accuracy: 0.9827 - val_loss: 0.0319 - val_accuracy: 0.9891
# Epoch 2988/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 0.9936 - val_loss: 0.0188 - val_accuracy: 0.9922
# Epoch 2989/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 0.9972 - val_loss: 0.0174 - val_accuracy: 0.9922
# Epoch 2990/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 0.0177 - val_accuracy: 0.9922
# Epoch 2991/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9974 - val_loss: 0.0178 - val_accuracy: 0.9922
# Epoch 2992/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9962 - val_loss: 0.0205 - val_accuracy: 0.9922
# Epoch 2993/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0181 - val_accuracy: 0.9907
# Epoch 2994/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 0.9954 - val_loss: 0.0177 - val_accuracy: 0.9907
# Epoch 2995/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9961 - val_loss: 0.0206 - val_accuracy: 0.9907
# Epoch 2996/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 0.9944 - val_loss: 0.0181 - val_accuracy: 0.9922
# Epoch 2997/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9964 - val_loss: 0.0160 - val_accuracy: 0.9922
# Epoch 2998/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9971 - val_loss: 0.0165 - val_accuracy: 0.9922
# Epoch 2999/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.9967 - val_loss: 0.0156 - val_accuracy: 0.9922
# Epoch 3000/3000
# 182/182 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 0.9968 - val_loss: 0.0182 - val_accuracy: 0.9907

# %% [markdown]
# ## GRAFICACIÓN DE RESULTADOS DE ENTRENAMIENTO

# %%
plt.figure(figsize=(16,6))
plt.grid()
len_epoch = len(history.history['accuracy'])
plt.plot(np.arange(0,len_epoch),history.history['accuracy'], label = 'accuracy',color=(0,0.81,0.8))
plt.plot(np.arange(0,len_epoch),history.history['val_accuracy'],label='val_accuracy',
         color=(1,0.6,0.45))
plt.legend()
plt.title('Precisión Entrenamiento',fontsize=14)
plt.xlabel('Epoca')
plt.ylabel('Precision')
plt.savefig(rs + '/04_ann_model/'+'execution_'+aux1+'_ann_results'+'/Precision_Entrenamiento.png')

plt.figure(figsize=(16,6))
plt.grid()
len_epoch = len(history.history['loss'])
plt.plot(np.arange(0,len_epoch),history.history['loss'], label = 'loss',color=(0,0.81,0.8))
plt.plot(np.arange(0,len_epoch),history.history['val_loss'],label='val_loss',color=(1,0.6,0.45))
plt.legend()
plt.title('Pérdida Entrenamiento',fontsize=14)
plt.xlabel('Epoca')
plt.ylabel('Perdida')
plt.savefig(rs + '/04_ann_model/' +'execution_'+aux1+'_ann_results' + '/Perdida_Entrenamiento.png')

# %% [markdown]
# ## EVALUACIÓN DE LA RED NEURONAL CON DATOS DE PRUEBA

# %%
corp_transf_test  = []

for i in x_test:
    aux  = [] 
    for j in i:
        aux.append(dict_pal_vec[j])
    prom = np.mean(np.array(aux),axis=0)
    corp_transf_test.append(list (prom))

corp_transf_test_np = np.array(corp_transf_test)

model.evaluate(corp_transf_test_np, np.array(y_test,dtype=int) - 1)
# Out:
# 51/51 [==============================] - 0s 1ms/step - loss: 0.0176 - accuracy: 0.9932
# [0.01764686219394207, 0.9931761622428894]

# %% [markdown]
# Los valores de error y precisión entre el entrenamiento, validación y test son muy similares. Los errores presentan valores bajos y precisiones muy altas superiores al $99.3\%$ de manera que el clasificador tiene un alto rendimiento.
