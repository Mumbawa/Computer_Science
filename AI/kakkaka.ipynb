# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/Mumbawa/Computer_Science/blob/main/AI/Untitle.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
# </table>

# %%
print('jdhdhdh')
# Out:
# jdhdhdh
